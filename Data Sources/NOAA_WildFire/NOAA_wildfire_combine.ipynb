# %%
import requests
import pandas as pd
import time
import os
from config import token
import sqlite3
import warnings
import calendar

# %%
def fetch_save_data(url, headers, params, csv_filename):
    results = []
    
    while True:
        response = requests.get(url, headers=headers, params=params)
        
        if response.status_code == 200:
            data = response.json()
            df = pd.DataFrame(data['results'])
            results.append(df)
            
            if len(df) < params['limit']:
                break
            
            params['offset'] += params['limit']
        else:
            print("Error:", response.status_code)
            break
    
    df_name = pd.concat(results, ignore_index=True)
    response_count = df_name.shape[0]
    print(f"Response Count for{csv_filename}: {response_count}")
    
    df_name.to_csv(csv_filename, index=False)
    return df_name

# Define the API endpoint URL, headers, pagination parameters, and base CSV filename
api_url = "https://www.ncei.noaa.gov/cdo-web/api/v2/data"
api_headers = {"token": token}
limit = 1000
offset= 0
datasetid = 'GSOM'
datatypeids = ['PRCP'] #'TMAX','TAVG','TMIN' 'PRCP'
locationid = 'FIPS:US'  # US FIPS code, california is 06

# Define the start and end dates for the range of months you want to fetch
start_year = 2019
start_month =12
end_year = 2019
end_month = 12  # Adjust this based on how many months you want to fetch

# Specify the number of designated iterations (months)
iterations = end_month - start_month + 1

# Loop through the specified range of months
for _ in range(iterations):
    start_date = f"{start_year}-{start_month:02d}-01"
    end_day = calendar.monthrange(start_year, start_month)[1]
    end_date = f"{start_year}-{start_month:02d}-{end_day:02d}"
    
    api_params = {
        'offset': offset,
        'datasetid': datasetid,
        'startdate': start_date,
        'enddate': end_date,
        'locationid': locationid,
        'limit': limit,
        'datatypeid': ','.join(datatypeids)
    }
    
    output_csv_filename = f"Outputs/US_data/prcp_{start_year}_{start_month:02d}.csv" #change between temp and prcp and others
    
    # Call the function with the defined values
    temp_df = fetch_save_data(api_url, api_headers, api_params, output_csv_filename)
    
    # Increment the start_month and start_year for the next iteration
    start_month += 1
    if start_month > 12:
        start_month = 1
        start_year += 1
# Out:
# Response Count forOutputs/US_data/prcp_2019_12.csv: 14848

# %%
# Combine all daily CSV files into a single DataFrame
combined_df = pd.concat([pd.read_csv(os.path.join("Outputs/US_data", file)) for file in os.listdir("Outputs/US_data")])

# Save the combined DataFrame as a CSV file
combined_csv_filename = 'Outputs/combined_data.csv'
combined_df.to_csv(combined_csv_filename, index=False)

combined_df.head()
# Out:
#                   date datatype            station attributes  value
# 0  2018-01-01T00:00:00     PRCP  GHCND:AQW00061705       ,,,W  390.3
# 1  2018-01-01T00:00:00     PRCP  GHCND:CA001018611       ,,,C  117.6
# 2  2018-01-01T00:00:00     PRCP  GHCND:CA001135126       ,,,C   67.6
# 3  2018-01-01T00:00:00     PRCP  GHCND:CA005020881       ,,,C    3.6
# 4  2018-01-01T00:00:00     PRCP  GHCND:CA006020559       ,,,C   21.6

# %%
combined_df.shape
# Out:
# (617457, 5)

# %%
def fetch_save_data(url, headers, params, csv_filename):
    results = []
    
    while True:
        response = requests.get(url, headers=headers, params=params)
        
        if response.status_code == 200:
            data = response.json()
            df = pd.DataFrame(data['results'])
            results.append(df)
            
            if len(df) < params['limit']:
                break
            
            params['offset'] += params['limit']
        else:
            print("Error:", response.status_code)
            break
    
    df_name = pd.concat(results, ignore_index=True)
    response_count = df_name.shape[0]
    print(f"Response Count: {response_count}")
    
    df_name.to_csv(csv_filename, index=False)
    return df_name

# %%
# Define the API endpoint URL, headers, pagination parameters, and CSV filename
api_url = "https://www.ncei.noaa.gov/cdo-web/api/v2/stations"
api_headers = {"token": token}
api_params = {'offset': 0, 
              'limit': 1000,
              'locationid': 'FIPS:US' #CA code is 06
             }
output_csv_filename = 'Outputs/full_station_list.csv'

# Call the function with the defined values
stations_df = fetch_save_data(api_url, api_headers, api_params, output_csv_filename)

stations_df.tail()

# %%
# Define the API endpoint URL, headers, pagination parameters, and CSV filename
api_url = "https://www.ncei.noaa.gov/cdo-web/api/v2/data"
api_headers = {"token": token}

# Set up pagination parameters
offset = 0
limit = 1000
datasetid = 'GSOM'
datatypeids = ['TAVG','TMIN','TMAX','PRCP']
startdate = '2018-01-01'
enddate = '2018-01-31'
locationid = 'FIPS:US'  # California FIPS code

api_params = {
    'datasetid': datasetid,
    'startdate': startdate,
    'locationid': locationid,
    'enddate': enddate,
    'offset': offset,
    'limit': limit
}

# Combine datatypeids into a comma-separated string
api_params['datatypeid'] = ','.join(datatypeids)

output_csv_filename = 'f(Outputs/US_data/prcp_{year}_{month}.csv)

# Call the function with the defined values
temp_df = fetch_save_data(api_url, api_headers, api_params, output_csv_filename)

# Display the first few rows of the DataFrame
temp_df.tail(10)

# %%
# Read the data from your CSV or Excel file
file_path = 'Outputs/combined_data.csv'
data_df = pd.read_csv(file_path)

# Convert 'value' column to float, handling invalid entries as NaN
data_df['value'] = pd.to_numeric(data_df['value'], errors='coerce')

# Initialize empty lists to store the data
dates = []
stations = []
tmax_values = []
tmin_values = []
tavg_values = []
prcp_values = []

# Iterate through the rows of the original DataFrame
for index, row in data_df.iterrows():
    date = row['date']
    station = row['station']
    datatype = row['datatype']
    value = row['value']
    
    if datatype == 'TMAX':
        tmax_values.append(value)
        tmin_values.append(None)
        tavg_values.append(None)
        prcp_values.append(None)
    elif datatype == 'TMIN':
        tmax_values.append(None)
        tmin_values.append(value)
        tavg_values.append(None)
        prcp_values.append(None)
    elif datatype == 'TAVG':
        tmax_values.append(None)
        tmin_values.append(None)
        tavg_values.append(value)
        prcp_values.append(None)
    elif datatype == 'PRCP':
        tmax_values.append(None)
        tmin_values.append(None)
        tavg_values.append(None)
        prcp_values.append(value)
    
    dates.append(date)
    stations.append(station)

# Create a new DataFrame
new_data = {
    'date': dates,
    'station': stations,
    'TMAX': tmax_values,
    'TMIN': tmin_values,
    'TAVG': tavg_values,
    'PRCP': prcp_values
}

new_df = pd.DataFrame(new_data)

# Convert all columns except 'date' and 'station' to float
float_columns = new_df.columns.difference(['date', 'station'])
new_df[float_columns] = new_df[float_columns].astype(float)

# Group by date and station and keep non-null values
grouped_df = new_df.groupby(['date', 'station']).first().reset_index()

# Write the grouped DataFrame to a CSV file
csv_filename = 'Outputs/grouped_df.csv'
grouped_df.to_csv(csv_filename, index=False)


# Print the first few rows of the grouped DataFrame
grouped_df.head()
# Out:
#                   date            station   TMAX   TMIN   TAVG   PRCP
# 0  2018-01-01T00:00:00  GHCND:AQW00061705  30.58  25.12  27.85  390.3
# 1  2018-01-01T00:00:00  GHCND:CA001018611   7.98   4.63   6.30  117.6
# 2  2018-01-01T00:00:00  GHCND:CA001135126   1.10  -5.44  -2.17   67.6
# 3  2018-01-01T00:00:00  GHCND:CA005020881  -8.93 -17.87 -13.40    3.6
# 4  2018-01-01T00:00:00  GHCND:CA006020559  -8.50 -19.77 -14.14   21.6

# %%
grouped_df.describe()
# Out:
#                TMAX          TMIN          TAVG           PRCP
# count  42742.000000  42571.000000  42450.000000  180603.000000
# mean      18.393210      5.704463     12.037469      91.247268
# std       10.955681     10.450637     10.565162      76.867685
# min      -13.780000    -27.680000    -20.530000       0.000000
# 25%        9.430000     -2.590000      3.340000      30.700000
# 50%       19.760000      5.810000     12.870000      76.500000
# 75%       28.010000     14.800000     21.380000     132.100000
# max       49.190000     35.390000     42.290000    1528.800000

# %%
grouped_df = grouped_df.dropna(subset=['TMAX', 'TMIN', 'TAVG','PRCP'])
grouped_df.head()
# Out:
#                   date            station   TMAX   TMIN   TAVG   PRCP
# 0  2018-01-01T00:00:00  GHCND:AQW00061705  30.58  25.12  27.85  390.3
# 1  2018-01-01T00:00:00  GHCND:CA001018611   7.98   4.63   6.30  117.6
# 2  2018-01-01T00:00:00  GHCND:CA001135126   1.10  -5.44  -2.17   67.6
# 3  2018-01-01T00:00:00  GHCND:CA005020881  -8.93 -17.87 -13.40    3.6
# 4  2018-01-01T00:00:00  GHCND:CA006020559  -8.50 -19.77 -14.14   21.6

# %%
# Folder containing the CSV files
folder = 'Outputs/US_data'

# List of CSV filenames
filenames = ['ca_station_temps_2018_2019_1.csv','ca_station_temps_2018_2019.csv']

# Initialize an empty DataFrame to store the combined data
combined_df = pd.DataFrame()

# Loop through the filenames and read each CSV into a DataFrame
for filename in filenames:
    file_path = os.path.join(folder, filename)
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        combined_df = pd.concat([combined_df, df], ignore_index=True)
    else:
        print(f"File not found: {file_path}")

# Remove duplicates from the combined DataFrame
combined_df = combined_df.drop_duplicates()

# Save the combined and deduplicated DataFrame to a new CSV file
output_filename = os.path.join('Outputs/combined_temps.csv')
combined_df.to_csv(output_filename, index=False)

print(f"Combined CSVs and removed duplicates. Saved as '{output_filename}'.")

# %%
# Read the data from your CSV or Excel file
file_path = 'Outputs/combined_temps.csv'
data_df = pd.read_csv(file_path)

# Convert 'value' column to float, handling invalid entries as NaN
data_df['value'] = pd.to_numeric(data_df['value'], errors='coerce')

# Initialize empty lists to store the data
dates = []
stations = []
tmax_values = []
tmin_values = []
tavg_values = []
prcp_values = []

# Iterate through the rows of the original DataFrame
for index, row in data_df.iterrows():
    date = row['date']
    station = row['station']
    datatype = row['datatype']
    value = row['value']
    
    if datatype == 'TMAX':
        tmax_values.append(value)
        tmin_values.append(None)
        tavg_values.append(None)
        prcp_values.append(None)
    elif datatype == 'TMIN':
        tmax_values.append(None)
        tmin_values.append(value)
        tavg_values.append(None)
        prcp_values.append(None)
    elif datatype == 'TAVG':
        tmax_values.append(None)
        tmin_values.append(None)
        tavg_values.append(value)
        prcp_values.append(None)
    elif datatype == 'PRCP':
        tmax_values.append(None)
        tmin_values.append(None)
        tavg_values.append(None)
        prcp_values.append(value)
    
    dates.append(date)
    stations.append(station)

# Create a new DataFrame
new_data = {
    'date': dates,
    'station': stations,
    'TMAX': tmax_values,
    'TMIN': tmin_values,
    'TAVG': tavg_values,
    'PRCP': prcp_values
}

new_df = pd.DataFrame(new_data)

# Convert all columns except 'date' and 'station' to float
float_columns = new_df.columns.difference(['date', 'station'])
new_df[float_columns] = new_df[float_columns].astype(float)

# Group by date and station and keep non-null values
grouped_df = new_df.groupby(['date', 'station']).first().reset_index()

# Drop rows with NaN values in 'TMAX', 'TMIN', and 'TAVG' columns
subset_columns = ['TMAX', 'TMIN', 'TAVG']
grouped_df = grouped_df.dropna(subset=subset_columns, how='all')

# Write the grouped DataFrame to a CSV file
csv_filename = 'Outputs/grouped_df.csv'
grouped_df.to_csv(csv_filename, index=False)

# Print the first few rows of the grouped DataFrame
grouped_df.head()

# %%
# Load the stations.csv file into stations_df
stations_df = pd.read_csv('Outputs/full_station_list.csv')
grouped_df= pd.read_csv('Outputs/grouped_df.csv')

# Merge the two DataFrames based on 'station' using a left join
grouped_df_detailed = pd.merge(grouped_df, stations_df, 
                               left_on='station', right_on='id', how='left')

# Drop the redundant columns (from stations_df)
grouped_df_detailed.drop(columns=['id'], inplace=True)

grouped_df_detailed=grouped_df_detailed[['station','name','latitude','longitude','elevation','date','maxdate','mindate','TAVG','TMAX','TMIN','PRCP']]

# Write the grouped DataFrame to a CSV file
csv_filename = 'Outputs/grouped_df_detailed.csv'
grouped_df_detailed.to_csv(csv_filename, index=False)

grouped_df_detailed.head()
# Out:
#              station                                          name  latitude  \
# 0  GHCND:AQW00061705  PAGO PAGO WEATHER SERVICE OFFICE AIRPORT, US -14.33056
# 1  GHCND:CA001018611                   VICTORIA GONZALES CS, WA US  48.03330
# 2  GHCND:CA001135126                                 MIDWAY, WA US  49.00000
# 3  GHCND:CA005020881                           EMERSON AUTO, ND US  49.00000
# 4  GHCND:CA006020559                                BARWICK, MN US  48.63330
#
#    longitude  elevation                 date     maxdate     mindate   TAVG  \
# 0 -170.71361        3.7  2018-01-01T00:00:00  2023-07-31  1945-08-01  27.85
# 1 -123.33330       70.0  2018-01-01T00:00:00  2023-07-31  1973-01-01   6.30
# 2 -118.76670      580.0  2018-01-01T00:00:00  2023-06-11  1987-06-01  -2.17
# 3  -97.23330      242.0  2018-01-01T00:00:00  2023-07-31  2009-07-01 -13.40
# 4  -93.96670      335.0  2018-01-01T00:00:00  2023-07-31  1978-12-01 -14.14
#
#     TMAX   TMIN   PRCP
# 0  30.58  25.12  390.3
# 1   7.98   4.63  117.6
# 2   1.10  -5.44   67.6
# 3  -8.93 -17.87    3.6
# 4  -8.50 -19.77   21.6

# %%
wildfires=pd.read_csv('Resources/data.csv')

# %%
wildfires.columns
# Out:
# Index(['OBJECTID', 'Shape', 'FOD_ID', 'FPA_ID', 'SOURCE_SYSTEM_TYPE',
#        'SOURCE_SYSTEM', 'NWCG_REPORTING_AGENCY', 'NWCG_REPORTING_UNIT_ID',
#        'NWCG_REPORTING_UNIT_NAME', 'SOURCE_REPORTING_UNIT',
#        'SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID',
#        'LOCAL_INCIDENT_ID', 'FIRE_CODE', 'FIRE_NAME',
#        'ICS_209_PLUS_INCIDENT_JOIN_ID', 'ICS_209_PLUS_COMPLEX_JOIN_ID',
#        'MTBS_ID', 'MTBS_FIRE_NAME', 'COMPLEX_NAME', 'FIRE_YEAR',
#        'DISCOVERY_DATE', 'DISCOVERY_DOY', 'DISCOVERY_TIME',
#        'NWCG_CAUSE_CLASSIFICATION', 'NWCG_GENERAL_CAUSE',
#        'NWCG_CAUSE_AGE_CATEGORY', 'CONT_DATE', 'CONT_DOY', 'CONT_TIME',
#        'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE', 'LONGITUDE', 'OWNER_DESCR',
#        'STATE', 'COUNTY', 'FIPS_CODE', 'FIPS_NAME'],
#       dtype='object')

# %%
wildfires=wildfires[['LATITUDE', 'LONGITUDE', 'FIRE_SIZE','NWCG_REPORTING_UNIT_NAME', 'FIRE_SIZE_CLASS', 'FIRE_YEAR',
       'FPA_ID', 'FIRE_CODE', 'NWCG_CAUSE_CLASSIFICATION',
       'NWCG_GENERAL_CAUSE', 'FIRE_NAME', 'DISCOVERY_DATE', 'CONT_DATE',
       'DISCOVERY_TIME', 'CONT_TIME', 'STATE', 'COUNTY', 'FIPS_CODE'
       ]]
wildfires=wildfires[
    (wildfires['FIRE_YEAR'].isin([2018]))
]
wildfires.head()
# Out:
#           LATITUDE   LONGITUDE  FIRE_SIZE    NWCG_REPORTING_UNIT_NAME  \
# 2045714  46.275833 -114.379167        0.1  Bitterroot National Forest
# 2045715  46.404167 -113.921944        0.1  Bitterroot National Forest
# 2045716  46.245833 -114.308889        1.0  Bitterroot National Forest
# 2045717  45.784722 -114.033056        0.1  Bitterroot National Forest
# 2045718  45.986944 -113.807222        0.1  Bitterroot National Forest
#
#         FIRE_SIZE_CLASS  FIRE_YEAR      FPA_ID FIRE_CODE  \
# 2045714               A       2018  FS-6911076      EKS4
# 2045715               A       2018  FS-6908885      L1RX
# 2045716               B       2018  FS-6898061      L49X
# 2045717               A       2018  FS-6890683      EKS4
# 2045718               A       2018  FS-6888073      EKS4
#
#         NWCG_CAUSE_CLASSIFICATION         NWCG_GENERAL_CAUSE      FIRE_NAME  \
# 2045714                   Natural                    Natural       BLODGETT
# 2045715                     Human  Equipment and vehicle use   CORLEY GULCH
# 2045716                     Human    Recreation and ceremony   CANYON CREEK
# 2045717                   Natural                    Natural  MAYNARD CREEK
# 2045718                   Natural                    Natural           BLUE
#
#         DISCOVERY_DATE  CONT_DATE  DISCOVERY_TIME  CONT_TIME STATE COUNTY  \
# 2045714      8/22/2018  8/22/2018          1625.0     1740.0    MT    081
# 2045715      7/26/2018  7/28/2018          1225.0     1653.0    MT    081
# 2045716      9/21/2018  9/23/2018          1305.0     1241.0    MT    081
# 2045717      8/17/2018        NaN          1723.0        NaN    MT    081
# 2045718      8/12/2018  8/12/2018          1031.0     1334.0    MT    081
#
#          FIPS_CODE
# 2045714    30081.0
# 2045715    30081.0
# 2045716    30081.0
# 2045717    30081.0
# 2045718    30081.0

# %%
wildfires.shape
# Out:
# (80860, 17)

# %%
#Takes 4-10 minutes to run
warnings.filterwarnings("ignore")

wildfires['DISCOVERY_DATE'] = pd.to_datetime(wildfires['DISCOVERY_DATE'])
grouped_df_detailed['date'] = pd.to_datetime(grouped_df_detailed['date'])

def find_nearest_match(row, df, date_col, lat_col, lon_col):
    date_diff = abs((df[date_col] - row['DISCOVERY_DATE']).dt.total_seconds())
    lat_diff = abs(df[lat_col] - row['LATITUDE'])
    lon_diff = abs(df[lon_col] - row['LONGITUDE'])
    total_diff = date_diff + lat_diff + lon_diff
    nearest_idx = total_diff.idxmin()
    return df.loc[nearest_idx]

# Create an empty list to hold the merged rows
merged_rows = []

# Iterate over each row in the filtered wildfires DataFrame
for idx, row in wildfires.iterrows():
    nearest_row = find_nearest_match(row, grouped_df_detailed, 'date', 'latitude', 'longitude')
    merged_row = pd.concat([row, nearest_row])
    merged_rows.append(merged_row)

# Concatenate the list of merged rows into a DataFrame
merged_results = pd.concat(merged_rows, axis=1).T

merged_results=merged_results[['LATITUDE', 'LONGITUDE','COUNTY', 'FIPS_CODE','FIRE_SIZE', 'FIRE_SIZE_CLASS',
       'NWCG_CAUSE_CLASSIFICATION', 'NWCG_GENERAL_CAUSE', 'FIRE_NAME',
       'DISCOVERY_DATE', 'CONT_DATE', 'DISCOVERY_TIME', 'CONT_TIME', 'STATE',
       'station', 'name', 'latitude', 'longitude', 'elevation', 'date', 'TAVG',
       'TMAX', 'TMIN','PRCP']]

merged_results.head(20)
# Out:
#      LATITUDE   LONGITUDE COUNTY FIPS_CODE FIRE_SIZE FIRE_SIZE_CLASS  \
# 0   46.275833 -114.379167    081   30081.0       0.1               A
# 1   46.404167 -113.921944    081   30081.0       0.1               A
# 2   46.245833 -114.308889    081   30081.0       1.0               B
# 3   45.784722 -114.033056    081   30081.0       0.1               A
# 4   45.986944 -113.807222    081   30081.0       0.1               A
# 5   46.023056 -113.799722    081   30081.0       0.1               A
# 6   45.913611   -114.6675    049   16049.0       0.1               A
# 7   46.121111 -114.239167    081   30081.0       0.1               A
# 8   45.868333 -113.804167    081   30081.0      0.25               A
# 9   45.914444 -114.635278    049   16049.0       0.1               A
# 10  45.938889 -114.271944    081   30081.0       0.1               A
# 11  46.016111 -113.807778    081   30081.0       0.1               A
# 12    45.9075 -114.626389    049   16049.0       0.1               A
# 13  45.885833 -114.038333    081   30081.0       0.1               A
# 14  46.017778 -113.772778    081   30081.0       1.0               B
# 15  46.023333    -113.775    081   30081.0       0.1               A
# 16  46.569444 -113.839167    081   30081.0       0.1               A
# 17  45.708333 -114.744444    049   16049.0       0.1               A
# 18  47.682778 -116.378611    055   16055.0       0.2               A
# 19  47.867778 -116.376944    055   16055.0       0.3               B
#
#    NWCG_CAUSE_CLASSIFICATION         NWCG_GENERAL_CAUSE      FIRE_NAME  \
# 0                    Natural                    Natural       BLODGETT
# 1                      Human  Equipment and vehicle use   CORLEY GULCH
# 2                      Human    Recreation and ceremony   CANYON CREEK
# 3                    Natural                    Natural  MAYNARD CREEK
# 4                    Natural                    Natural           BLUE
# 5                    Natural                    Natural       POLLYWOG
# 6                    Natural                    Natural          CEDAR
# 7                    Natural                    Natural  DOUBLE STRIKE
# 8                    Natural                    Natural         MEADOW
# 9                    Natural                    Natural    MT GEORGE 2
# 10                   Natural                    Natural  NORTH TRAPPER
# 11                   Natural                    Natural   MARTIN CREEK
# 12                   Natural                    Natural      MT GEORGE
# 13                   Natural                    Natural            ELK
# 14                   Natural                    Natural      HOPE LAKE
# 15                   Natural                    Natural        CHARITY
# 16                     Human    Recreation and ceremony       CINNABAR
# 17                   Natural                    Natural  HAYSTACK FIRE
# 18                   Natural                    Natural      JOHN PEAK
# 19                   Natural                    Natural       HAMILTON
#
#    DISCOVERY_DATE  ...            station                         name  \
# 0      2018-08-22  ...  GHCND:USC00243885              HAMILTON, MT US
# 1      2018-07-26  ...  GHCND:US1MTRV0009  STEVENSVILLE 5.7 SSE, MT US
# 2      2018-09-21  ...  GHCND:USC00243885              HAMILTON, MT US
# 3      2018-08-17  ...  GHCND:USC00242221                 DARBY, MT US
# 4      2018-08-12  ...  GHCND:USC00247967            SULA 14 NE, MT US
# 5      2018-08-11  ...  GHCND:USC00247967            SULA 14 NE, MT US
# 6      2018-07-25  ...  GHCND:USC00108246          SELWAY LODGE, ID US
# 7      2018-06-08  ...  GHCND:USC00242221                 DARBY, MT US
# 8      2018-08-17  ...  GHCND:USC00247967            SULA 14 NE, MT US
# 9      2018-07-24  ...  GHCND:USC00108246          SELWAY LODGE, ID US
# 10     2018-08-17  ...  GHCND:USC00242221                 DARBY, MT US
# 11     2018-08-11  ...  GHCND:USC00247967            SULA 14 NE, MT US
# 12     2018-07-23  ...  GHCND:USC00108246          SELWAY LODGE, ID US
# 13     2018-08-21  ...  GHCND:USC00242221                 DARBY, MT US
# 14     2018-08-12  ...  GHCND:USC00247967            SULA 14 NE, MT US
# 15     2018-08-11  ...  GHCND:USC00247967            SULA 14 NE, MT US
# 16     2018-09-13  ...  GHCND:US1MTRV0005       FLORENCE 3.7 SE, MT US
# 17     2018-07-17  ...  GHCND:USC00108246          SELWAY LODGE, ID US
# 18     2018-07-27  ...  GHCND:US1IDKT0022  COEUR D ALENE 4.0 SE, ID US
# 19     2018-07-28  ...  GHCND:USC00100667   BAYVIEW MODEL BASIN, ID US
#
#      latitude   longitude elevation       date   TAVG   TMAX  TMIN   PRCP
# 0    46.24622  -114.16794    1092.7 2018-09-01  12.89  21.95  3.82    3.5
# 1   46.427776 -114.058279    1075.9 2018-08-01    NaN    NaN   NaN   12.2
# 2    46.24622  -114.16794    1092.7 2018-10-01   6.96  13.28  0.65   33.7
# 3     46.0263   -114.1763    1182.6 2018-09-01  11.77  20.79  2.74    9.1
# 4      45.911   -113.7394    1571.2 2018-08-01   15.1  26.09  4.12   19.4
# 5      45.911   -113.7394    1571.2 2018-08-01   15.1  26.09  4.12   19.4
# 6     46.0081   -114.8442     786.4 2018-08-01  19.38  31.89  6.88   21.1
# 7     46.0263   -114.1763    1182.6 2018-06-01  14.62  21.15  8.09  102.7
# 8      45.911   -113.7394    1571.2 2018-09-01   9.69  20.79 -1.42   11.2
# 9     46.0081   -114.8442     786.4 2018-08-01  19.38  31.89  6.88   21.1
# 10    46.0263   -114.1763    1182.6 2018-09-01  11.77  20.79  2.74    9.1
# 11     45.911   -113.7394    1571.2 2018-08-01   15.1  26.09  4.12   19.4
# 12    46.0081   -114.8442     786.4 2018-08-01  19.38  31.89  6.88   21.1
# 13    46.0263   -114.1763    1182.6 2018-09-01  11.77  20.79  2.74    9.1
# 14     45.911   -113.7394    1571.2 2018-08-01   15.1  26.09  4.12   19.4
# 15     45.911   -113.7394    1571.2 2018-08-01   15.1  26.09  4.12   19.4
# 16   46.60683   -114.0124    1085.1 2018-09-01    NaN    NaN   NaN    5.4
# 17    46.0081   -114.8442     786.4 2018-08-01  19.38  31.89  6.88   21.1
# 18     47.663    -116.715     880.3 2018-08-01    NaN    NaN   NaN   21.4
# 19    47.9804   -116.5594     636.1 2018-08-01  17.32  25.85   8.8   11.0
#
# [20 rows x 24 columns]

# %%
name_counts = merged_results['name'].value_counts()

# Print the sum of all counts
total_count = name_counts.sum()
print(f"Total Count: {total_count}")

# Print the unique names and their counts
for name, count in name_counts.items():
    print(f"Name: {name}, Count: {count}")
# Out:
# Total Count: 80860
# Name: RED LAKE INDIAN AGCY, MN US, Count: 380
# Name: PHOENIX 2.6 NNW, AZ US, Count: 293
# Name: PHOENIX 5.4 NE, AZ US, Count: 191
# Name: FRESNO 2.4 NW, CA US, Count: 187
# Name: PHOENIX 3.8 NNW, AZ US, Count: 187
# Name: NEW ROCKFORD 7.0 ESE, ND US, Count: 187
# Name: GLENDALE 3.5 S, AZ US, Count: 181
# Name: FRESNO 5 NE, CA US, Count: 173
# Name: TUCSON 3.0 WNW, AZ US, Count: 169
# Name: CAVE CREEK 9.4 WSW, AZ US, Count: 161
# Name: ANTHEM 0.9 NE, AZ US, Count: 161
# Name: AVONDALE 3.8 NE, AZ US, Count: 160
# Name: YUMA 7.7 SE, AZ US, Count: 158
# Name: BUNCH 0.8 N, OK US, Count: 150
# Name: GLENDALE 2.5 ENE, AZ US, Count: 139
# Name: MADERA, CA US, Count: 138
# Name: MODESTO 4.1 NW, CA US, Count: 137
# Name: TURLOCK NUMBER 2, CA US, Count: 135
# Name: PHOENIX 9.2 NE, AZ US, Count: 133
# Name: WILLOW CREEK 4.9 NNE, CA US, Count: 128
# Name: SWAN FALLS PH, ID US, Count: 127
# Name: BAKERSFIELD 5 NW, CA US, Count: 124
# Name: MESA 1.3 W, AZ US, Count: 121
# Name: BELCOURT KEYA RADIO, ND US, Count: 119
# Name: MERCED 1.2 NW, CA US, Count: 118
# Name: SAN CARLOS RESERVOIR, AZ US, Count: 114
# Name: TUCSON 6.4 SSE, AZ US, Count: 112
# Name: KINGMAN 5.6 NNE, AZ US, Count: 112
# Name: ELSINORE, CA US, Count: 110
# Name: TUCSON 2.5 WNW, AZ US, Count: 109
# Name: PHOENIX 5.5 SSE, AZ US, Count: 109
# Name: ANTHEM 1.7 NW, AZ US, Count: 107
# Name: PLEASANT VALLEY, AZ US, Count: 106
# Name: MESA 1.6 ENE, AZ US, Count: 104
# Name: MINNEWAUKAN, ND US, Count: 100
# Name: HAMLET, NC US, Count: 99
# Name: MCRAE 6.6 SE, GA US, Count: 98
# Name: WICHITA 1.2 NNW, KS US, Count: 98
# Name: RIALTO 2.1 N, CA US, Count: 98
# Name: PHOENIX 6.3 SSW, AZ US, Count: 92
# Name: TOPEKA NWS, KS US, Count: 91
# Name: GRAVOIS MILLS 8.4 S, MO US, Count: 91
# Name: CONCORD 2.1 SE, CA US, Count: 91
# Name: EAST GLACIER, MT US, Count: 91
# Name: STOCKTON 3.3 SE, CA US, Count: 90
# Name: FANSHAWE, OK US, Count: 89
# Name: RIVERSIDE 5.8 E, CA US, Count: 87
# Name: LOS BANOS, CA US, Count: 86
# Name: RUSK, TX US, Count: 86
# Name: TEMPE ASU, AZ US, Count: 85
# Name: WEST NYACK 1.3 WSW, NY US, Count: 85
# Name: BOISE LUCKY PEAK DAM, ID US, Count: 84
# Name: TEMPE 2.1 WSW, AZ US, Count: 83
# Name: DIANA 2 W, TX US, Count: 83
# Name: BRIGHT ANGEL RANGER STATION, AZ US, Count: 83
# Name: RIO GRANDE CITY 17.7 NE, TX US, Count: 82
# Name: INDIO FIRE STATION, CA US, Count: 81
# Name: LANDER 0.9 W, WY US, Count: 80
# Name: GLENDALE 10.7 NNE, AZ US, Count: 79
# Name: TUCSON 8.3 WSW, AZ US, Count: 78
# Name: REDLANDS, CA US, Count: 78
# Name: SCOTTSDALE 7.8 SSW, AZ US, Count: 76
# Name: SUNNYSLOPE 1.6 W, CA US, Count: 75
# Name: MECCA FIRE STATION, CA US, Count: 75
# Name: TUCSON 5.0 NNW, AZ US, Count: 74
# Name: GOODYEAR 2.9 W, AZ US, Count: 74
# Name: HEBER ARIZONA, AZ US, Count: 74
# Name: TOPEKA 3.2 WSW, KS US, Count: 73
# Name: DECATUR, TX US, Count: 72
# Name: MOUNT PLEASANT, TX US, Count: 72
# Name: TUCSON 5.3 SSW, AZ US, Count: 71
# Name: PELTON DAM, OR US, Count: 71
# Name: PHOENIX 6.7 WSW, AZ US, Count: 71
# Name: OVERLAND PARK 1.7 NE, KS US, Count: 71
# Name: VISALIA, CA US, Count: 70
# Name: TUCSON 2.8 WNW, AZ US, Count: 70
# Name: ECHO DAM, UT US, Count: 69
# Name: HENDERSON 7.0 SSW, TX US, Count: 68
# Name: STOCKTON 0.6 NW, UT US, Count: 68
# Name: BLANDING, UT US, Count: 68
# Name: SCOTLAND, TX US, Count: 67
# Name: GOODYEAR 5.9 WSW, AZ US, Count: 67
# Name: ROCHESTER 3.4 NNW, NY US, Count: 67
# Name: BETATAKIN, AZ US, Count: 67
# Name: BAXLEY 1.8 SSE, GA US, Count: 67
# Name: MOUNT VERNON, GA US, Count: 66
# Name: OBERLIN FIRE TOWER, LA US, Count: 66
# Name: KEENE 3 S, ND US, Count: 66
# Name: WORLAND 2.8 NE, WY US, Count: 66
# Name: CAMP PARDEE, CA US, Count: 66
# Name: COLORADO SPRINGS 3.0 S, CO US, Count: 65
# Name: ROSEVILLE 2.4 SE, CA US, Count: 64
# Name: LAUGHLIN, NV US, Count: 64
# Name: GILBERT 3.8 NW, AZ US, Count: 64
# Name: ALTON, UT US, Count: 64
# Name: LEESVILLE, LA US, Count: 64
# Name: BEAUMONT 2.1 ESE, CA US, Count: 64
# Name: FORT DUCHESNE, UT US, Count: 63
# Name: DELTA 3 E, CO US, Count: 63
# Name: PLAINS 5.2 N, MT US, Count: 63
# Name: GLOBE NUMBER 3, AZ US, Count: 62
# Name: TULIA, TX US, Count: 62
# Name: RUSHVILLE 11.6 NNW, NE US, Count: 62
# Name: NAHUNTA 6 S, GA US, Count: 62
# Name: FARMINGTON AG SCIENCE CNT, NM US, Count: 62
# Name: FITZGERALD 4.3 N, GA US, Count: 62
# Name: OAK CITY 0.3 SSE, UT US, Count: 61
# Name: SWAINSBORO 0.9 W, GA US, Count: 61
# Name: SAN BERNARDINO 5.1 NW, CA US, Count: 60
# Name: PHOENIX 6.0 NNE, AZ US, Count: 59
# Name: COOL RIDGE 0.4 NE, WV US, Count: 59
# Name: CHANDLER 3.8 N, AZ US, Count: 58
# Name: DAISY 4 ENE, OK US, Count: 58
# Name: WEST, TX US, Count: 58
# Name: WACO 4.1 NE, TX US, Count: 58
# Name: MESA 4.3 SW, AZ US, Count: 58
# Name: KINGMAN 2.7 ENE, AZ US, Count: 58
# Name: TOPEKA 2.1 WSW, KS US, Count: 57
# Name: TUCSON 4.9 E, AZ US, Count: 57
# Name: GUADALUPE 7.2 SW, AZ US, Count: 57
# Name: EAST MESA, AZ US, Count: 57
# Name: PAYSON 6.3 NNE, AZ US, Count: 56
# Name: SCREVEN 2.3 ENE, GA US, Count: 56
# Name: DUBLIN 6.3 SW, GA US, Count: 56
# Name: LIPAN 4 NW, TX US, Count: 55
# Name: BATTIEST, OK US, Count: 55
# Name: BURLINGAME 3.5 NNE, KS US, Count: 55
# Name: GOLDEN VALLEY 2.6 WNW, AZ US, Count: 55
# Name: DUBLIN 2, GA US, Count: 55
# Name: DEVIL MOUNTAIN ALASKA, AK US, Count: 54
# Name: MURRIETA 3.6 NNE, CA US, Count: 54
# Name: EVANS 2.0 NNW, WA US, Count: 53
# Name: EAST ROCHESTER 0.1 NNW, NY US, Count: 53
# Name: THORNTON 2.3 SSE, CO US, Count: 53
# Name: MERCED, CA US, Count: 53
# Name: FEDSCREEK 1 SE, KY US, Count: 53
# Name: WINNEMUCCA 3 SSW, NV US, Count: 53
# Name: SAN JACINTO, CA US, Count: 52
# Name: PHOENIX 8.8 NNW, AZ US, Count: 52
# Name: DONALSONVILLE, GA US, Count: 52
# Name: FREMONT, CA US, Count: 52
# Name: CANYON DE CHELLY, AZ US, Count: 52
# Name: EPHRAIM, UT US, Count: 52
# Name: TUCSON 1.5 NNE, AZ US, Count: 52
# Name: LAKE MADERA 1.3 NNE, CA US, Count: 52
# Name: WALDEN 1.2 S, NY US, Count: 52
# Name: SCOTTSDALE 11.6 NNW, AZ US, Count: 51
# Name: ALBERTON, MT US, Count: 51
# Name: HOLLY HILL 1 SW, SC US, Count: 51
# Name: BELLVILLE 2.8 N, GA US, Count: 51
# Name: TEMPE 4.0 SW, AZ US, Count: 50
# Name: WICHITA 4.5 ENE, KS US, Count: 50
# Name: PLACERVILLE 3.7 SW, CA US, Count: 50
# Name: HYANNIS, MA US, Count: 50
# Name: PASO ROBLES, CA US, Count: 50
# Name: YOUNGTOWN, AZ US, Count: 50
# Name: HELM 2.7 NNE, CA US, Count: 50
# Name: GAINESVILLE 5 ENE, TX US, Count: 50
# Name: PUEBLO 2.5 SSW, CO US, Count: 50
# Name: NOGALES 6 N, AZ US, Count: 50
# Name: FAIRBANKS 7.2 ENE, AK US, Count: 50
# Name: PHOENIX 5.6 N, AZ US, Count: 49
# Name: SANDERS, AZ US, Count: 49
# Name: ALTAMONT, UT US, Count: 49
# Name: MEXIA 9.4 SSE, TX US, Count: 49
# Name: HANFORD 3.6 N, CA US, Count: 49
# Name: MARYSVILLE 5.0 N, CA US, Count: 49
# Name: RED SPRINGS 3.8 NW, NC US, Count: 49
# Name: LINCOLN 1.3 SSW, CA US, Count: 49
# Name: BREMOND, TX US, Count: 48
# Name: SPANISH FORK 1.0 W, UT US, Count: 48
# Name: LAKE FORK RESERVOIR, TX US, Count: 48
# Name: HILLSBORO, TX US, Count: 48
# Name: INEZ 2 E, KY US, Count: 48
# Name: GRANGER 2.3 NNE, WA US, Count: 48
# Name: TUCSON 5.3 WNW, AZ US, Count: 47
# Name: BIG SANDY 3.9 E, TX US, Count: 47
# Name: SPOKANE 5.7 SSE, WA US, Count: 47
# Name: STRAWN 8 NNE, TX US, Count: 47
# Name: BUCKEYE 7.8 SE, AZ US, Count: 47
# Name: JERICHO, TX US, Count: 47
# Name: TEEC NOS POS, AZ US, Count: 47
# Name: NORTH BEND 5.4 ESE, WA US, Count: 47
# Name: MARKLEY COVE, CA US, Count: 47
# Name: BAKERSFIELD 6.1 WSW, CA US, Count: 47
# Name: TUCSON 8.0 NW, AZ US, Count: 47
# Name: POPLAR BLUFF 4.2 NW, MO US, Count: 47
# Name: LAUGHLIN 1.2 SSW, NV US, Count: 46
# Name: BRIGHTON 1.7 ESE, CO US, Count: 46
# Name: OKANOGAN 1.2 NE, WA US, Count: 46
# Name: NICOLAUS NUMBER 2, CA US, Count: 46
# Name: BULLARD 3.7 E, TX US, Count: 46
# Name: LAKE CITY 7.9 SSW, FL US, Count: 46
# Name: AUBERRY 2 NW, CA US, Count: 46
# Name: BLUE RIDGE RANGER STATION, AZ US, Count: 46
# Name: SAGINAW NUMBER 3, MI US, Count: 45
# Name: MURRIETA 4.3 ENE, CA US, Count: 45
# Name: KITE, GA US, Count: 45
# Name: COLORADO SPRINGS 3.7 ENE, CO US, Count: 45
# Name: DERBY 2.9 N, KS US, Count: 45
# Name: COLORADO SPRINGS 1.1 NE, CO US, Count: 45
# Name: NORWOOD NUMBER 2, CO US, Count: 45
# Name: HELENA 2.0 NNW, MT US, Count: 45
# Name: ANDREWS, SC US, Count: 44
# Name: GERBER 3.5 SW, CA US, Count: 44
# Name: BONNER SPRINGS, KS US, Count: 44
# Name: IGNACIO 6 ESE, CO US, Count: 44
# Name: YAKIMA 0.9 WNW, WA US, Count: 44
# Name: MANOR 3.0 NW, GA US, Count: 44
# Name: SONORA, CA US, Count: 44
# Name: ROCHESTER 5.0 WNW, NY US, Count: 44
# Name: NEWMAN, CA US, Count: 44
# Name: LAKE CITY 2 SE, SC US, Count: 44
# Name: WARRENSBURG 1.1 NNE, MO US, Count: 43
# Name: KINGSTREE 6.9 SE, SC US, Count: 43
# Name: TWITCHELL DAM, CA US, Count: 43
# Name: OSAWATOMIE, KS US, Count: 43
# Name: TRACY CARBONA, CA US, Count: 43
# Name: ANCHORAGE 4.7 SSW, AK US, Count: 43
# Name: AMARILLO 4.8 WSW, TX US, Count: 43
# Name: LAKE PARK 2.8 W, GA US, Count: 43
# Name: AVINGER 6.6 S, TX US, Count: 43
# Name: LITCHFIELD PARK 0.4 N, AZ US, Count: 43
# Name: SALINAS 3.2 NNW, CA US, Count: 43
# Name: SANFORD DAM, TX US, Count: 42
# Name: MOUNT LEMMON WILLOW CANYON, AZ US, Count: 42
# Name: ROSEVILLE 4.7 WNW, CA US, Count: 42
# Name: CLOVIS 1.3 NE, CA US, Count: 42
# Name: GATESVILLE 9.8 SW, TX US, Count: 42
# Name: KREBS 0.3 WNW, OK US, Count: 42
# Name: TALKEETNA 7.6 S, AK US, Count: 42
# Name: WESTMINSTER 3.9 S, CO US, Count: 42
# Name: BENGAL 4 NNW, OK US, Count: 42
# Name: KIRBYVILLE 1.5 SE, TX US, Count: 42
# Name: MESA VERDE NATIONAL PARK, CO US, Count: 42
# Name: FIVE POINTS 5 SSW, CA US, Count: 41
# Name: FAIRBANKS 6.3 W, AK US, Count: 41
# Name: COLUMBUS, KS US, Count: 41
# Name: AMARILLO 9.9 WNW, TX US, Count: 41
# Name: TEMPE 3.6 NNW, AZ US, Count: 41
# Name: ALBEMARLE, NC US, Count: 41
# Name: RIFLE 3 ENE, CO US, Count: 31
# Name: REDDING 7.9 NNE, CA US, Count: 31
# Name: HENRIETTA 0.7 WSW, TX US, Count: 31
# Name: BEOWAWE, NV US, Count: 31
# Name: LIVERMORE, CA US, Count: 31
# Name: SANDERSVILLE, GA US, Count: 31
# Name: LAURINBURG, NC US, Count: 31
# Name: PINE GROVE FIRE TOWER, LA US, Count: 31
# Name: HARDIN, MT US, Count: 31
# Name: MCNARY 2 N, AZ US, Count: 31
# Name: GOLDENDALE 4.2 NNW, WA US, Count: 31
# Name: FORT SMITH 0.5 ENE, MT US, Count: 31
# Name: VALDOSTA 4.8 WSW, GA US, Count: 31
# Name: SPOKANE 5.5 S, WA US, Count: 31
# Name: LAKE HAVASU CITY, AZ US, Count: 31
# Name: BURKBURNETT 1.2 WSW, TX US, Count: 31
# Name: BALCH POWER HOUSE, CA US, Count: 30
# Name: ELIZABETHTOWN, NC US, Count: 30
# Name: SAM RAYBURN DAM, TX US, Count: 30
# Name: WICKENBURG 2.6 WSW, AZ US, Count: 30
# Name: PINETOP 2 E, AZ US, Count: 30
# Name: MANNING, SC US, Count: 30
# Name: SUMTER 6.8 NNE, SC US, Count: 30
# Name: POPLAR 20.4 N, MT US, Count: 30
# Name: SAN FRANCISCO 1.1 SW, CA US, Count: 30
# Name: PAGOSA SPRINGS 1 SE, CO US, Count: 30
# Name: BARBOURSVILLE 1.1 NW, VA US, Count: 30
# Name: PITTSBURG 0.7 WSW, KS US, Count: 30
# Name: WOODLAND PARK 1.1 NNW, CO US, Count: 30
# Name: HENDERSON 6.1 NW, TX US, Count: 30
# Name: CECIL 5.6 ENE, WI US, Count: 30
# Name: DILLEY 0.4 SSW, TX US, Count: 30
# Name: BROCKTON, MA US, Count: 30
# Name: OAKDALE 2.4 NE, CA US, Count: 30
# Name: MINERAL POINT 7.3 ENE, WI US, Count: 30
# Name: EASTON, KS US, Count: 30
# Name: TONGANOXIE 5 SE, KS US, Count: 30
# Name: PRINEVILLE 2.6 ENE, OR US, Count: 30
# Name: COWICHE 1.6 WSW, WA US, Count: 30
# Name: SYLVESTER 5.5 WSW, GA US, Count: 30
# Name: WINTHROP 4.1 WNW, WA US, Count: 30
# Name: CAVE JUNCTION 0.4 ENE, OR US, Count: 30
# Name: MC LAUGHLIN 2 SW, SD US, Count: 30
# Name: HARRY L. ENGLEBRIGHT DAM, CA US, Count: 30
# Name: AQUILLA 1.3 NNE, TX US, Count: 30
# Name: HANNAWA FALLS 0.1 SW, NY US, Count: 29
# Name: HUDSON 4.8 WSW, CO US, Count: 29
# Name: RIVERSIDE MUNICIPAL AIRPORT, CA US, Count: 29
# Name: EDMORE 3.8 ESE, MI US, Count: 29
# Name: SAINT JOHNS, AZ US, Count: 29
# Name: BRONSON 3.0 SE, FL US, Count: 29
# Name: HEBER CITY 10.1 ESE, UT US, Count: 29
# Name: MONCKS CORNER 4 N, SC US, Count: 29
# Name: NAPLES 2.8 SSE, UT US, Count: 29
# Name: TAZEWELL 2.9 WNW, VA US, Count: 27
# Name: BROWNWOOD 2 NE, TX US, Count: 27
# Name: REDVALE 22.8 SW, CO US, Count: 27
# Name: PUEBLO 1.1 ENE, CO US, Count: 27
# Name: MAYETTA 5.5 WSW, KS US, Count: 27
# Name: HORSESHOE BAY 2.7 S, TX US, Count: 27
# Name: MESA 13.6 ESE, AZ US, Count: 27
# Name: HOLTON, KS US, Count: 27
# Name: PAINTED DESERT NATIONAL PARK, AZ US, Count: 27
# Name: PINETOP LAKESIDE 1.4 NNW, AZ US, Count: 27
# Name: VALDOSTA 2.8 NNW, GA US, Count: 27
# Name: LAKE HAVASU 3.5 NE, AZ US, Count: 27
# Name: BREWTON 3 ENE, AL US, Count: 27
# Name: OROVILLE, CA US, Count: 27
# Name: LAKE KEMP, TX US, Count: 27
# Name: SHOAL CREEK ESTATES 0.2 SE, MO US, Count: 27
# Name: MARLOW 0.0 S, GA US, Count: 27
# Name: CHERAW, SC US, Count: 27
# Name: MENAHGA 0.7 N, MN US, Count: 27
# Name: WEST PLAINS, MO US, Count: 27
# Name: FORT STEWART, GA US, Count: 27
# Name: MITCHELL 2 E, OR US, Count: 27
# Name: JEFFERSON, TX US, Count: 27
# Name: RANGELY 1 E, CO US, Count: 27
# Name: PIRU 2 ESE, CA US, Count: 27
# Name: GISELA, AZ US, Count: 27
# Name: HOLTER DAM, MT US, Count: 27
# Name: GLENWOOD, NM US, Count: 27
# Name: GRANBURY 3.9 SSW, TX US, Count: 27
# Name: SUNSET CRATER NATIONAL MONUMENT, AZ US, Count: 27
# Name: ARTESIA 0.5 W, CA US, Count: 27
# Name: KOPPERL 5.2 WNW, TX US, Count: 27
# Name: LIVE OAK 10.0 W, FL US, Count: 27
# Name: BEN WHEELER 2.4 N, TX US, Count: 27
# Name: MESA 4.7 ENE, AZ US, Count: 26
# Name: PLAZA, ND US, Count: 26
# Name: QUEENSBURY 2.5 E, NY US, Count: 26
# Name: LUBBOCK 6.4 NW, TX US, Count: 26
# Name: PENRYN 0.4 SE, CA US, Count: 26
# Name: GRAND CANYON VISITOR CENTER, AZ US, Count: 26
# Name: WOLF POINT, MT US, Count: 26
# Name: LODGEPOLE, CA US, Count: 26
# Name: TRADITION 5.6 W, FL US, Count: 26
# Name: SNOWFLAKE 1.4 SW, AZ US, Count: 26
# Name: PITTSBURG, KS US, Count: 26
# Name: LUMBERTON 8.6 SSE, NC US, Count: 26
# Name: LAKESIDE, MO US, Count: 26
# Name: SARALAND 6.8 NNW, AL US, Count: 26
# Name: ANTHEM 1.7 NNW, AZ US, Count: 26
# Name: HOLBROOK 4.0 NNE, ID US, Count: 26
# Name: CRESCENT CITY 5.5 NNE, CA US, Count: 26
# Name: MC HENRY 3 W, ND US, Count: 26
# Name: BRYAN 7.1 N, TX US, Count: 26
# Name: GAUTIER 4.9 N, MS US, Count: 26
# Name: TUCSON 5.8 E, AZ US, Count: 26
# Name: BEND 17.1 SSW, OR US, Count: 26
# Name: WALNUT SPRINGS 7.9 NW, TX US, Count: 26
# Name: NEW MELONES DAM HQ, CA US, Count: 26
# Name: LAKE OF THE PINES 1.0 WSW, CA US, Count: 26
# Name: BROKEN BOW 1 N, OK US, Count: 26
# Name: EUREKA RANGER STATION, MT US, Count: 26
# Name: HENDERSON, TX US, Count: 26
# Name: PURVIS 2 N, MS US, Count: 26
# Name: GRAND MARSH 1.9 SSW, WI US, Count: 26
# Name: GREENVILLE 5.6 S, TX US, Count: 26
# Name: GILBERT 3.9 SE, AZ US, Count: 26
# Name: EL MORRO NATIONAL MON, NM US, Count: 26
# Name: MOUNT SHASTA 0.8 ESE, CA US, Count: 26
# Name: MADISONVILLE, TX US, Count: 26
# Name: SOMERVILLE DAM, TX US, Count: 26
# Name: YUCAIPA 1.5 NNE, CA US, Count: 26
# Name: WOODLAND 1 WNW, CA US, Count: 26
# Name: HOYT 2 SE, KS US, Count: 26
# Name: MISSOULA 4.4 W, MT US, Count: 26
# Name: IDYLLWILD FIRE DEPARTMENT, CA US, Count: 26
# Name: PERRY LAKE, KS US, Count: 26
# Name: HARDIN 0.6 ENE, MT US, Count: 25
# Name: DENVER 4.3 WNW, CO US, Count: 25
# Name: HEFLIN, AL US, Count: 25
# Name: BIG CYPRESS, FL US, Count: 25
# Name: SHIRLEY 2.9 N, NY US, Count: 25
# Name: PARADISE, CA US, Count: 25
# Name: CORNELL 4.1 W, WI US, Count: 25
# Name: HAZARD WATER WKS, KY US, Count: 25
# Name: DANVILLE 3.3 W, GA US, Count: 25
# Name: LANDER 1.7 NNW, WY US, Count: 25
# Name: CULEBRA HILL, US, Count: 25
# Name: TUCSON 8.1 E, AZ US, Count: 25
# Name: KINGSLEY 2.7 ENE, MI US, Count: 25
# Name: JUNEAU 5.6 NW, AK US, Count: 25
# Name: MARIPOSA 3.7 NNW, CA US, Count: 25
# Name: ORANGE 9 N, TX US, Count: 25
# Name: KENT CITY 2 SW, MI US, Count: 25
# Name: INDEPENDENCE, KS US, Count: 25
# Name: PINEDALE 13.8 NW, WY US, Count: 25
# Name: PINNACLES NATIONAL PARK, CA US, Count: 25
# Name: CHANDLER 4.9 ESE, AZ US, Count: 25
# Name: WITTMANN 0.5 ESE, AZ US, Count: 25
# Name: LUDLOW 2.3 SW, MA US, Count: 25
# Name: CEDAR BREAKS N.M., UT US, Count: 25
# Name: DEVINE 0.4 S, TX US, Count: 25
# Name: EUSTACE 7.3 NE, TX US, Count: 25
# Name: SALYERSVILLE WATER WORKS, KY US, Count: 25
# Name: MISSOULA 6 NW WEATHER FORECAST OFFICE, MT US, Count: 25
# Name: SEDONA 0.4 SSW, AZ US, Count: 25
# Name: TUCSON 5.2 NNW, AZ US, Count: 25
# Name: GRAND RAPIDS 2.9 NW, MI US, Count: 25
# Name: REPUBLIC 8.4 NNE, WA US, Count: 25
# Name: PORT CHARLOTTE 6.2 W, FL US, Count: 25
# Name: BIG SANDY 6.6 N, TX US, Count: 25
# Name: NAVARRO MILLS DAM, TX US, Count: 25
# Name: GRAND MARSH 1.0 W, WI US, Count: 20
# Name: ABILENE 6 ESE, TX US, Count: 20
# Name: COARSEGOLD 4 SE, CA US, Count: 20
# Name: WEATHER FORECAST OFFICE PUEBLO, CO US, Count: 20
# Name: DOTHAN, AL US, Count: 20
# Name: SONNETTE 7 SW, MT US, Count: 20
# Name: REEVESVILLE 1.0 SSE, SC US, Count: 20
# Name: BLACK RIVER PUMPS, AZ US, Count: 20
# Name: NEWCASTLE 0.6 SSW, UT US, Count: 20
# Name: EAST GRAND RAPIDS, MI US, Count: 20
# Name: BELOIT 0.7 ESE, WI US, Count: 20
# Name: WICHITA 2.5 WNW, KS US, Count: 20
# Name: ALTON, MO US, Count: 20
# Name: WHITE CLOUD 2.9 NW, MI US, Count: 20
# Name: BAGGS 0.2 NNW, WY US, Count: 20
# Name: COMANCHE 7.0 ENE, TX US, Count: 20
# Name: ROCKFORD 0.9 NNE, MI US, Count: 20
# Name: AURORA 2.1 ESE, CO US, Count: 20
# Name: MOUNTAIN 1.1 SW, WI US, Count: 20
# Name: PAW PAW 3.6 NNE, MI US, Count: 20
# Name: KOSSE 4.0 E, TX US, Count: 20
# Name: ROCKLIN 2.5 W, CA US, Count: 20
# Name: TUCSON 8.5 ESE, AZ US, Count: 20
# Name: PLYMOUTH 5.3 WSW, WI US, Count: 20
# Name: PORTAGE 5.7 WSW, WI US, Count: 20
# Name: GRANT GROVE, CA US, Count: 20
# Name: ALTENBERN, CO US, Count: 20
# Name: MANHATTAN, KS US, Count: 20
# Name: UKIAH 8.4 NW, CA US, Count: 20
# Name: RUNGE, TX US, Count: 20
# Name: FARMVILLE 1.0 SSW, VA US, Count: 20
# Name: BEND, OR US, Count: 20
# Name: TIZER GARDENS, MT US, Count: 20
# Name: CORTEZ 1.2 SW, CO US, Count: 20
# Name: VALLECITO DAM, CO US, Count: 20
# Name: MEDORA, ND US, Count: 20
# Name: COMMERCE 4 SW, TX US, Count: 20
# Name: WALNUT CANYON NATIONAL MONUMENT, AZ US, Count: 20
# Name: KING, NC US, Count: 20
# Name: HELPER 0.3 SW, UT US, Count: 20
# Name: FRUIT HEIGHTS 1.3 N, UT US, Count: 20
# Name: JACKSON 3.2 W, MI US, Count: 20
# Name: NORCO 1.2 S, CA US, Count: 20
# Name: THE WOODLANDS 1.8 SE, TX US, Count: 20
# Name: LINCOLN 0.4 NNE, MO US, Count: 20
# Name: RAEFORD 5.0 NE, NC US, Count: 20
# Name: SCOTTS VALLEY 1.4 W, CA US, Count: 20
# Name: UPPER SAN LEANDRO FILTERS, CA US, Count: 20
# Name: PERRY 2.0 S, FL US, Count: 20
# Name: LEAKESVILLE 6 WSW, MS US, Count: 20
# Name: POWELL 3.9 ENE, WY US, Count: 20
# Name: HART 3 WSW, MI US, Count: 20
# Name: KESWICK 2.8 NE, VA US, Count: 20
# Name: RHODHISS HYDRO PLANT, NC US, Count: 20
# Name: LAKE SHARPE PROJECT, SD US, Count: 20
# Name: DUPREE 15 SSE, SD US, Count: 20
# Name: LENOX DALE, MA US, Count: 1
# Name: UNION 3.0 NW, ME US, Count: 1
# Name: CHATHAM TWP 1.1 NNW, NJ US, Count: 1
# Name: SALISBURY, NC US, Count: 1
# Name: YORK SPRINGS 0.7 SE, PA US, Count: 1
# Name: NORTH FORK 2, NC US, Count: 1
# Name: BERNHEIM FOREST, KY US, Count: 1
# Name: HOLLY SPRINGS 1.0 NNE, GA US, Count: 1
# Name: FLAT ROCK 1.5 S, NC US, Count: 1
# Name: MAMMOTH CAVE, KY US, Count: 1
# Name: SODDY DAISY MOWBRAY MOUNTAIN, TN US, Count: 1
# Name: MC HENRY 4.8 SSE, MD US, Count: 1
# Name: CLEVELAND 5.2 SE, TN US, Count: 1
# Name: LEVERETT NUMBER 2, MA US, Count: 1
# Name: ALTOONA 1.5 SSE, IA US, Count: 1
# Name: TIJERAS 8.0 SSE, NM US, Count: 1
# Name: BASTROP 0.6 WNW, TX US, Count: 1
# Name: HOT SPRINGS 6.5 SW, NC US, Count: 1
# Name: HARRISBURG 1 NE, PA US, Count: 1
# Name: EDDYVILLE 5 S, KY US, Count: 1
# Name: PLACITAS 2.0 E, NM US, Count: 1
# Name: INTERLACHEN 10.4 NNE, FL US, Count: 1
# Name: NEW HOLLAND 2 SE, PA US, Count: 1
# Name: WINCHESTER 5 SE, TN US, Count: 1
# Name: BLUE MARSH LAKE, PA US, Count: 1
# Name: HUMBOLDT 4.6 NNW, NE US, Count: 1
# Name: MILAN 0.2 NNW, NM US, Count: 1
# Name: LOWDEN, IA US, Count: 1
# Name: NEW MARKET 4.7 N, IA US, Count: 1
# Name: DAKOTA 4.8 NW, IL US, Count: 1
# Name: ASHEVILLE 5.6 NNW, NC US, Count: 1
# Name: HAYS 8.9 NNE, KS US, Count: 1
# Name: MC CLUSKY, ND US, Count: 1
# Name: WEST POINT 5.0 WNW, NE US, Count: 1
# Name: DWIGHT 4.1 NNW, IL US, Count: 1
# Name: WALLACE, KS US, Count: 1
# Name: CEDAR CREST 0.5 NNW, NM US, Count: 1
# Name: VALLE CRUCIS 1.4 SSE, NC US, Count: 1
# Name: GALENA 0.3 S, MD US, Count: 1
# Name: ENKA, NC US, Count: 1
# Name: FULTON 3.4 SW, MO US, Count: 1
# Name: SOMERSET, PA US, Count: 1
# Name: GLADEVILLE, TN US, Count: 1
# Name: SANDIA HEIGHTS 0.2 WNW, NM US, Count: 1
# Name: SPRING GROVE, PA US, Count: 1
# Name: EVERETT, PA US, Count: 1
# Name: STATESVILLE 8.3 WSW, NC US, Count: 1
# Name: DWIGHT 0.1 SE, KS US, Count: 1
# Name: AUBURN 5 ESE, NE US, Count: 1
# Name: ARLINGTON 5.5 SSE, KS US, Count: 1
# Name: WARM MINERAL SPRINGS 5.0 WSW, FL US, Count: 1
# Name: SUMTER 1.9 W, SC US, Count: 1
# Name: BEACH 0.3 SSE, ND US, Count: 1
# Name: BURNSVILLE 1.5 WNW, NC US, Count: 1
# Name: RALEIGH 2.2 NNW, NC US, Count: 1
# Name: KINGSPORT, TN US, Count: 1
# Name: MOULTON 2, AL US, Count: 1
# Name: CHULUOTA 0.9 N, FL US, Count: 1
# Name: MORRISTOWN 5.3 W, TN US, Count: 1
# Name: LEECHBURG 1.4 SW, PA US, Count: 1
# Name: ABBEVILLE 3.3 WNW, SC US, Count: 1
# Name: ALCALDE 10.8 NW, NM US, Count: 1
# Name: BOLIVIA 7.8 SW, NC US, Count: 1
# Name: WEST PELZER, SC US, Count: 1
# Name: CARTHAGE 2.5 NE, NY US, Count: 1
# Name: LIBERTY 1.1 SE, KY US, Count: 1
# Name: PORT CHARLOTTE 8.0 SW, FL US, Count: 1
# Name: COLLEGEDALE 2.8 WNW, TN US, Count: 1
# Name: TULLAHOMA, TN US, Count: 1
# Name: GASTONIA 1.8 SSE, NC US, Count: 1
# Name: LAKEWOOD PARK 0.5 SW, FL US, Count: 1
# Name: INVERNESS 2.6 ENE, FL US, Count: 1
# Name: CUBA, KS US, Count: 1
# Name: PERU 4.1 ESE, NY US, Count: 1
# Name: GREEN LANE 0.9 ESE, PA US, Count: 1
# Name: MIFFLINBURG 2 NW, PA US, Count: 1
# Name: ETNA 2.9 N, WY US, Count: 1
# Name: RAINSBURG 5.0 NNW, PA US, Count: 1
# Name: TOWSON 0.8 SW, MD US, Count: 1
# Name: ANSON, TX US, Count: 1
# Name: RUSSELL SPRINGS 3 N, KS US, Count: 1
# Name: MANVILLE 0.4 WSW, RI US, Count: 1
# Name: PRESTON 1.2 SE, KS US, Count: 1
# Name: CASCADE 5 S, MT US, Count: 1
# Name: DECATURVILLE, TN US, Count: 1
# Name: GRANITEVILLE 3.9 ENE, SC US, Count: 1
# Name: MCCLOUD, CA US, Count: 1
# Name: MCDONOUGH 7.5 NE, GA US, Count: 1
# Name: TAOS 2.6 SW, NM US, Count: 1
# Name: WEST UNION 1.9 ESE, SC US, Count: 1
# Name: HELEN 9.5 ENE, GA US, Count: 1
# Name: STERLING 3.1 ESE, NE US, Count: 1
# Name: PEACHTREE CITY 2.9 SSE, GA US, Count: 1
# Name: HAY SPRINGS 12.3 SSW, NE US, Count: 1
# Name: ALBUQUERQUE 8.2 ENE, NM US, Count: 1
# Name: HOLTS SUMMIT 2.5 NNE, MO US, Count: 1
# Name: FAIRBURY 8.0 NNW, NE US, Count: 1
# Name: POTTER 5.4 ESE, NE US, Count: 1
# Name: WEAVERVILLE 4.2 N, NC US, Count: 1
# Name: LAKE CITY 4.4 NNW, MN US, Count: 1
# Name: WHITE SIGNAL, NM US, Count: 1
# Name: UNDERWOOD, IA US, Count: 1
# Name: EVERLY 3 WNW, IA US, Count: 1
# Name: ATHENS 3.2 NW, GA US, Count: 1
# Name: WARNER ROBINS 0.3 W, GA US, Count: 1
# Name: TIGNALL 10.2 NE, GA US, Count: 1
# Name: WINNSBORO 12.5 ENE, SC US, Count: 1
# Name: MOUNT PLEASANT 6.4 NE, SC US, Count: 1
# Name: NORTH FALMOUTH 0.5 ENE, MA US, Count: 1
# Name: GILA 3.4 ENE, NM US, Count: 1
# Name: ROCA 5.0 NNE, NE US, Count: 1
# Name: MAYWOOD 10.4 S, NE US, Count: 1
# Name: ABILENE 5.4 E, KS US, Count: 1
# Name: LA PORTE 10.0 NNW, CO US, Count: 1
# Name: JAMAICA 3.2 S, IA US, Count: 1
# Name: DEATH VALLEY NATIONAL PARK, CA US, Count: 1
# Name: DECORAH, IA US, Count: 1
# Name: SIERRA VISTA 0.4 ESE, AZ US, Count: 1
# Name: MINDEN, NE US, Count: 1
# Name: DEMOREST 6.2 WNW, GA US, Count: 1
# Name: GLENWILLARD DASHIELDS LOCK AND DAM, PA US, Count: 1
# Name: WASHINGTON TWP 2.1 NNW, NJ US, Count: 1
# Name: BEECH MOUNTAIN, NC US, Count: 1
# Name: PINE CITY 3.1 SE, NY US, Count: 1
# Name: TECUMSEH 1 S, NE US, Count: 1
# Name: LEBANON 3.2 SW, NJ US, Count: 1
# Name: ST. AUGUSTINE 12.2 WNW, FL US, Count: 1
# Name: MONTGOMERY 3.8 ESE, TX US, Count: 1
# Name: ROSENDALE 2 E, NY US, Count: 1
# Name: ISABELLA 2.0 NNW, MO US, Count: 1
# Name: BUFFALO 2 N, MO US, Count: 1
# Name: STAMFORD 5 N, CT US, Count: 1
# Name: QUEMADO 14.1 NE, NM US, Count: 1
# Name: LAURENS 1.1 SSW, SC US, Count: 1
# Name: NASHUA 2 SW, IA US, Count: 1
# Name: RIDGE SPRING 0.4 SSW, SC US, Count: 1
# Name: LA GRANGE 10.6 ESE, GA US, Count: 1
# Name: ELSMERE 9 ENE, NE US, Count: 1
# Name: CLEVELAND 4.7 S, TN US, Count: 1
# Name: SOUTH CORNING 4.7 S, NY US, Count: 1
# Name: DENISON, IA US, Count: 1
# Name: ROCKBRIDGE 4.7 SSW, OH US, Count: 1
# Name: MONTGOMERY 12.9 S, AL US, Count: 1
# Name: JACKSONVILLE 11.4 ESE, FL US, Count: 1
# Name: HENDERSONVILLE 3.1 WNW, NC US, Count: 1
# Name: TRYON, NC US, Count: 1
# Name: QUENEMO 7.1 N, KS US, Count: 1
# Name: SNOW HILL 4 N, MD US, Count: 1
# Name: HARTWELL DAM, GA US, Count: 1
# Name: TALLADEGA 8.8 NW, AL US, Count: 1
# Name: REHOBOTH 2.1 N, MA US, Count: 1
# Name: KNIGHTDALE 4.7 SSE, NC US, Count: 1
# Name: GREENVILLE 2.8 WSW, NC US, Count: 1
# Name: KINSTON AG RESEARCH, NC US, Count: 1
# Name: DUBUQUE 1.4 WSW, IA US, Count: 1
# Name: GAYLORD BAY, NC US, Count: 1
# Name: IONIA, KS US, Count: 1
# Name: WEBSTER CITY 0.5 NW, IA US, Count: 1
# Name: CLAYTON 5.7 SSE, NC US, Count: 1
# Name: BONNERS FERRY 3.5 SSE, ID US, Count: 1
# Name: ALBION 1.9 NW, NY US, Count: 1
# Name: RALEIGH 6.9 N, NC US, Count: 1
# Name: LOUISIANA, MO US, Count: 1
# Name: STEWARTSVILLE 2.8 NNE, MO US, Count: 1
# Name: EWING, NE US, Count: 1
# Name: RICHLAND 2.95 W, NE US, Count: 1
# Name: SAC CITY, IA US, Count: 1
# Name: LEWISBURG, PA US, Count: 1
# Name: STROMSBURG 0.9 E, NE US, Count: 1
# Name: LA GRANGE 6.4 SSE, GA US, Count: 1
# Name: CLINTON 5.8 SW, NC US, Count: 1
# Name: HENDERSON 1.1 NNW, TN US, Count: 1
# Name: CHAPEL HILL 1.8 NE, NC US, Count: 1
# Name: NORTHAMPTON 0.4 S, MA US, Count: 1
# Name: CENTER POINT 2.1 SE, AL US, Count: 1
# Name: NORTHBRIDGE 2, MA US, Count: 1
# Name: VIRGINIA CITY, NV US, Count: 1
# Name: FOLEY 4.5 SE, AL US, Count: 1
# Name: KARTCHNER CAVERNS, AZ US, Count: 1
# Name: OAKLAND, IA US, Count: 1
# Name: ETOWAH 1.1 WNW, NC US, Count: 1
# Name: FLETCHER 2.5 E, NC US, Count: 1
# Name: ROULETTE 1.8 NNE, PA US, Count: 1
# Name: FLORENCE 0.9 W, CO US, Count: 1
# Name: SYRACUSE 1 NE, KS US, Count: 1
# Name: HAMPSTEAD 0.3 NW, NC US, Count: 1
# Name: CLARKESVILLE, GA US, Count: 1
# Name: VARYSBURG 3.1 E, NY US, Count: 1
# Name: REDDING 8.8 NE, CA US, Count: 1
# Name: CROSSVILLE EXPERIMENTAL STATION, TN US, Count: 1
# Name: TUBAC 2.9 SW, AZ US, Count: 1
# Name: JAMESVILLE 6.1 SW, NC US, Count: 1
# Name: COVINGTON 3 SW, TN US, Count: 1
# Name: ADAMSTOWN 2.5 SSE, PA US, Count: 1
# Name: EAGLE LAKE 2.0 WNW, FL US, Count: 1
# Name: COLLINSVILLE 0.4 NNE, MS US, Count: 1
# Name: COROLLA 5.8 SSE, NC US, Count: 1
# Name: UTICA 0.1 SSE, NE US, Count: 1
# Name: ALBANY 3.8 S, MN US, Count: 1
# Name: DUNDEE 0.3 NW, FL US, Count: 1
# Name: PALM BAY 2.6 SSE, FL US, Count: 1
# Name: KUTZTOWN 2.2 NNE, PA US, Count: 1
# Name: CENTENNIAL 1.1 NNE, WY US, Count: 1
# Name: MOBILE 4.5 WSW, AL US, Count: 1
# Name: CRESTED BUTTE 6.2 N, CO US, Count: 1
# Name: DWIGHT, IL US, Count: 1
# Name: LANCASTER 2 NE FILT PLANT, PA US, Count: 1
# Name: AIKEN 8.6 SE, SC US, Count: 1
# Name: OAK CREEK 0.3 WSW, CO US, Count: 1
# Name: EATONTOWN 1.2 NE, NJ US, Count: 1
# Name: NORTH BRANCH 2.4 WSW, MN US, Count: 1
# Name: RAGLAND 2 SSW, AL US, Count: 1
# Name: PAWLEYS ISLAND 2.7 W, SC US, Count: 1
# Name: WEST FALMOUTH 0.1 NNW, ME US, Count: 1
# Name: DRESDEN 1.5 NW, ME US, Count: 1
# Name: BRIMFIELD 3.6 NW, MA US, Count: 1
# Name: GOVE 4 W, KS US, Count: 1
# Name: CARNESVILLE, GA US, Count: 1
# Name: TOWER DNR, MN US, Count: 1
# Name: CARLOS 2 WSW, MN US, Count: 1
# Name: ORANGE CITY, IA US, Count: 1
# Name: KNIGHTDALE 1.9 WSW, NC US, Count: 1
# Name: ATKINSON 2.6 NNE, IL US, Count: 1
# Name: SOMERSET 2.0 NNE, MA US, Count: 1
# Name: RIDGE 1.8 SE, NY US, Count: 1
# Name: FLEETWOOD 2.0 ESE, PA US, Count: 1
# Name: ZEBULON 0.6 W, NC US, Count: 1
# Name: PIKEVILLE 13.2 NE, TN US, Count: 1
# Name: POINT MARION 1.0 SE, PA US, Count: 1
# Name: CRANSTON 1.2 SSE, RI US, Count: 1
# Name: SAYRE 2.8 WNW, PA US, Count: 1
# Name: ROME 3.7 SW, NY US, Count: 1
# Name: GRAND MARAIS, MN US, Count: 1
# Name: LUBBOCK 7.2 S, TX US, Count: 1
# Name: PALM CITY 1.4 NW, FL US, Count: 1
# Name: GAINESVILLE 8.1 SW, FL US, Count: 1
# Name: GODDARD 0.7 N, KS US, Count: 1
# Name: COON RAPIDS 1.4 ESE, MN US, Count: 1
# Name: GUTHRIE CENTER, IA US, Count: 1
# Name: LANCASTER 2.0 NNW, SC US, Count: 1
# Name: MONTICELLO 4.8 WNW, MN US, Count: 1
# Name: BELTON 4.1 SSW, SC US, Count: 1
# Name: ELK RIVER, MN US, Count: 1
# Name: JANSEN 5.8 E, NE US, Count: 1
# Name: WOBIC 0.5 ESE, MI US, Count: 1
# Name: WILLIAMSTON 0.9 SSW, NC US, Count: 1
# Name: BAILEYS HARBOR 2.3 WNW, WI US, Count: 1
# Name: CORVALLIS 4.2 ENE, MT US, Count: 1
# Name: SHREVEPORT 6.2 S, LA US, Count: 1
# Name: BLACHLY 0.5 W, OR US, Count: 1
# Name: LARAMIE 2.1 ENE, WY US, Count: 1
# Name: KALISPELL 2.6 NE, MT US, Count: 1
# Name: STREETER 5 NW, ND US, Count: 1
# Name: QUINCY DAM 21, IL US, Count: 1
# Name: COFFEEVILLE, MS US, Count: 1
# Name: BROOMFIELD 1.6 ENE, CO US, Count: 1
# Name: ELLSWORTH 7.4 NW, ME US, Count: 1
# Name: MONROE 7.1 SW, NC US, Count: 1
# Name: BEAUFORT 3.0 E, SC US, Count: 1
# Name: DE LEON SPRINGS 1.8 ENE, FL US, Count: 1
# Name: VIDOR 7.2 N, TX US, Count: 1
# Name: JACKSON 6.0 NE, MS US, Count: 1
# Name: HANCOCK 0.3 S, VT US, Count: 1
# Name: SADDLEBROOKE 1.5 ESE, AZ US, Count: 1
# Name: HUNTINGTON 1.0 S, WV US, Count: 1
# Name: MAXWELL 1.5 NE, TX US, Count: 1
# Name: FROMBERG 2.7 NE, MT US, Count: 1
# Name: KERRVILLE 3 NNE, TX US, Count: 1
# Name: ALBION 3.5 S, NE US, Count: 1
# Name: CROFTON 4.4 WNW, NE US, Count: 1
# Name: HILLSBOROUGH 7.4 NW, NC US, Count: 1
# Name: BEAUMONT RESRCH CTR, TX US, Count: 1
# Name: COVINGTON 1 NNW, MI US, Count: 1
# Name: JACKSON 2.3 WNW, MO US, Count: 1
# Name: CLINTON 0.7 NW, SC US, Count: 1
# Name: EDGAR 2.4 NW, NE US, Count: 1
# Name: GLIDE 1.1 SE, OR US, Count: 1
# Name: PORT ORFORD 1.5 ESE, OR US, Count: 1
# Name: STAYTON 8.4 E, OR US, Count: 1
# Name: TWO HARBORS, MN US, Count: 1
# Name: NEW ENGLAND, ND US, Count: 1
# Name: MOUNT HOREB 3.6 SSW, WI US, Count: 1
# Name: WINDSOR 1.1 W, ME US, Count: 1
# Name: FAIRFIELD 2.1 N, ND US, Count: 1
# Name: ZIMMERMAN 0.6 S, MN US, Count: 1
# Name: BEND 2.5 NW, OR US, Count: 1
# Name: GRAFTON 6.8 N, ND US, Count: 1
# Name: SPRINGFIELD 6.4 E, OR US, Count: 1
# Name: MONTICELLO 6.4 ENE 45, MN US, Count: 1
# Name: BUCKSPORT 3.3 NNW, ME US, Count: 1
# Name: WHITE PINE 2.0 NE, TN US, Count: 1
# Name: ELLSWORTH 1.4 S, WI US, Count: 1
# Name: ORCHARD LAKE VILLAGE 0.9 WSW, MI US, Count: 1
# Name: TIFFIN 1.8 SW, IA US, Count: 1
# Name: WEST TISBURY 2.9 N, MA US, Count: 1
# Name: FORT DODGE 1.6 ENE, IA US, Count: 1
# Name: SEBASTIAN 1.7 SSE, FL US, Count: 1
# Name: LAPORTE, PA US, Count: 1
# Name: EWING TWP 1.2 N, NJ US, Count: 1
# Name: MONTROSE 4.0 W, CO US, Count: 1
# Name: ENTERPRISE 0.4 W, KS US, Count: 1
# Name: ERIE 5.6 SW, PA US, Count: 1
# Name: NEW MORGAN 1.8 WNW, PA US, Count: 1
# Name: STATE COLLEGE 2.6 NW, PA US, Count: 1
# Name: MANTER 4.0 NW, KS US, Count: 1
# Name: LA JUNTA 17.5 S, CO US, Count: 1
# Name: FREDERICKTOWN 4.0 NNW, OH US, Count: 1
# Name: MOUNT CARROLL, IL US, Count: 1
# Name: HUGOTON, KS US, Count: 1
# Name: NORTH BRUNSWICK TWP 1.5 W, NJ US, Count: 1
# Name: LINWOOD 0.7 SSW, NJ US, Count: 1
# Name: FARMINGTON 0.6 SW, ME US, Count: 1
# Name: CONWAY 2.9 NW, MA US, Count: 1
# Name: NEW SALEM 3.1 S, MA US, Count: 1
# Name: GRUNDY CENTER, IA US, Count: 1
# Name: GALENA, IL US, Count: 1
# Name: CONWAY SPRINGS 4 SW, KS US, Count: 1
# Name: WASHTA, IA US, Count: 1
# Name: BREWSTER 10.45 WNW, NE US, Count: 1
# Name: COLUMBIA 2.3 SE, MO US, Count: 1
# Name: MEMPHIS, MO US, Count: 1
# Name: CARROLL, IA US, Count: 1
# Name: HEENEY 0.5 NW, CO US, Count: 1
# Name: STONINGTON 8.6 SE, CO US, Count: 1
# Name: FREEVILLE 3.7 W, NY US, Count: 1
# Name: HOBART 4.8 ESE, NY US, Count: 1
# Name: NORTH SMITHFIELD 0.6 S, RI US, Count: 1
# Name: LAWNDALE 0.1 NW, NC US, Count: 1
# Name: MONTROSE 0.4 ENE, PA US, Count: 1
# Name: TITUSVILLE WATER WORKS, PA US, Count: 1
# Name: VAIL 2.6 E, CO US, Count: 1
# Name: TROY 3.2 NNE, WV US, Count: 1
# Name: JAMESPORT 1.3 ESE, MO US, Count: 1
# Name: BASTROP 5.9 SSW, TX US, Count: 1
# Name: EDGEWATER 2.4 N, FL US, Count: 1
# Name: BEACONSFIELD 3 N, IA US, Count: 1
# Name: WASHINGTON TWP 3.6 W, NJ US, Count: 1
# Name: COLLBRAN 0.2 ESE, CO US, Count: 1
# Name: ANSELMO 6.5 E, NE US, Count: 1
# Name: BELLINGHAM 2.4 S, MA US, Count: 1
# Name: CABIN CREEK, CO US, Count: 1
# Name: CLUTIER, IA US, Count: 1
# Name: SUGAR GROVE 4.5 ENE, OH US, Count: 1
# Name: DRESDEN 2.3 SW, ME US, Count: 1
# Name: DOWNSVILLE DAM, NY US, Count: 1
# Name: SUDBURY 1.6 N, MA US, Count: 1
# Name: CASCADE, IA US, Count: 1
# Name: NORTH ENGLISH, IA US, Count: 1
# Name: KNOB LICK 4 S, KY US, Count: 1
# Name: EAST BETHEL 1.1 NNW, MN US, Count: 1
# Name: EDGEMONT 0.4 W, SD US, Count: 1
# Name: YAMPA, CO US, Count: 1
# Name: BRUSH 0.8 S, CO US, Count: 1
# Name: LOGANVILLE 4.0 E, GA US, Count: 1
# Name: TOULON 0.1 WNW, IL US, Count: 1
# Name: WABASHA 0.9 NNE, MN US, Count: 1
# Name: BREVARD 2.2 SSW, NC US, Count: 1
# Name: GOULD 4 SE S F S P, CO US, Count: 1
# Name: KENSINGTON 5.9 NE, MN US, Count: 1
# Name: MEADOWBROOK 1.7 E, AL US, Count: 1
# Name: HOKAH 4.5 WSW, MN US, Count: 1
# Name: WELLFLEET 3.0 E, MA US, Count: 1
# Name: BROCK 4.8 WSW, NE US, Count: 1
# Name: GENESEO, IL US, Count: 1
# Name: BANNER ELK, NC US, Count: 1
# Name: LAUREL SUMMIT, PA US, Count: 1
# Name: BARNES 0.2 N, KS US, Count: 1
# Name: OAKLAND 1 SE, MD US, Count: 1
# Name: MOUNT STERLING 2.4 W, KY US, Count: 1
# Name: WELLINGTON 12.7 NNW, CO US, Count: 1
# Name: WASHINGTON, MO US, Count: 1
# Name: CORVALLIS 1.5 NW, OR US, Count: 1
# Name: MIDDLETON, MA US, Count: 1
# Name: ROCKSPRINGS 8.5 WSW, TX US, Count: 1
# Name: PERU, IL US, Count: 1
# Name: PUNTA GORDA 1.4 NNW, FL US, Count: 1
# Name: TAUNTON 2.4 W, MA US, Count: 1
# Name: CHARLES CITY, IA US, Count: 1
# Name: DUBUQUE NUMBER 3, IA US, Count: 1
# Name: FLAGLER BEACH 2.3 SSE, FL US, Count: 1
# Name: HARMONY, MN US, Count: 1
# Name: SALUDA 0.5 N, NC US, Count: 1
# Name: PEAPACK GLADSTONE 1.3 NNE, NJ US, Count: 1
# Name: GAFFNEY 1.0 SE, SC US, Count: 1
# Name: HAMLIN 0.6 WSW, TX US, Count: 1
# Name: LITTLETON 6.4 W, CO US, Count: 1
# Name: COZAD 7.2 E, NE US, Count: 1
# Name: BIG HORN 0.3 ESE, WY US, Count: 1
# Name: SHERIDAN 3.4 SSE, IL US, Count: 1
# Name: MC MINNVILLE, TN US, Count: 1
# Name: MANSFIELD 5.1 WSW, OH US, Count: 1
# Name: DURHAM 1.2 W, CT US, Count: 1

# %%
us_data_2018_2019.columns
# Out:
# Index(['LATITUDE', 'LONGITUDE', 'FIRE_SIZE', 'FIRE_SIZE_CLASS',
#        'NWCG_CAUSE_CLASSIFICATION', 'DISCOVERY_DATE', 'CONT_DATE', 'STATE',
#        'station', 'name', 'latitude', 'longitude', 'elevation', 'date', 'TAVG',
#        'TMAX', 'TMIN'],
#       dtype='object')

# %%
warnings.filterwarnings("ignore")

us_data_2018_test = merged_results[['FIRE_NAME', 'STATE', 'FIPS_CODE', 'LATITUDE', 'LONGITUDE', 'DISCOVERY_DATE', 'CONT_DATE', 'name', 'latitude', 'longitude', 'date',
                                    'NWCG_CAUSE_CLASSIFICATION', 'FIRE_SIZE', 'FIRE_SIZE_CLASS',
                                    'elevation', 'TAVG', 'TMAX', 'TMIN','PRCP']]

# Rename the columns
us_data_2018_test.columns = ['FIRE_NAME', 'STATE', 'FIPS_CODE', 'FIRE_LATITUDE', 'FIRE_LONGITUDE', 'FIRE_DATE', 'CONTAIN_DATE', 'CLOSEST_STATION', 'STATION_LAT', 'STATION_LON', 'READINGS_DATE',
                               'CAUSE_CLASSIFICATION', 'FIRE_SIZE', 'FIRE_SIZE_CLASS',
                             'ELEVATION', 'TAVG', 'TMAX', 'TMIN','PRCP']


# Calculate the difference between 'CONTAIN_DATE' and 'FIRE_DATE'
us_data_2018_test['CONTAIN_DATE'] = pd.to_datetime(us_data_2018_test['CONTAIN_DATE'])
us_data_2018_test['DAYS_TO_CONTAIN'] = (us_data_2018_test['CONTAIN_DATE'] - us_data_2018_test['FIRE_DATE']).dt.days

# Replace any NaN values in 'DAYS_TO_CONTAIN' with 1
us_data_2018_test['DAYS_TO_CONTAIN'].fillna(0, inplace=True)

float_columns = {
    'FIRE_LATITUDE': float,
    'FIRE_LONGITUDE': float,
    'STATION_LAT': float,
    'STATION_LON': float,
    'FIRE_SIZE': float,
    'ELEVATION': float,
    'TAVG': float,
    'TMAX': float,
    'TMIN': float,
    'PRCP': float
}

int_columns = {
    'DAYS_TO_CONTAIN': int,
}

csv_filename = 'Outputs/us_data_2018.csv'
us_data_2018_test.to_csv(csv_filename, index=False)

us_data_2018_test = us_data_2018_test.astype({**float_columns, **int_columns})

us_data_2018_test.head(20)
# Out:
#         FIRE_NAME STATE FIPS_CODE  FIRE_LATITUDE  FIRE_LONGITUDE  FIRE_DATE  \
# 0        BLODGETT    MT   30081.0      46.275833     -114.379167 2018-08-22
# 1    CORLEY GULCH    MT   30081.0      46.404167     -113.921944 2018-07-26
# 2    CANYON CREEK    MT   30081.0      46.245833     -114.308889 2018-09-21
# 3   MAYNARD CREEK    MT   30081.0      45.784722     -114.033056 2018-08-17
# 4            BLUE    MT   30081.0      45.986944     -113.807222 2018-08-12
# 5        POLLYWOG    MT   30081.0      46.023056     -113.799722 2018-08-11
# 6           CEDAR    ID   16049.0      45.913611     -114.667500 2018-07-25
# 7   DOUBLE STRIKE    MT   30081.0      46.121111     -114.239167 2018-06-08
# 8          MEADOW    MT   30081.0      45.868333     -113.804167 2018-08-17
# 9     MT GEORGE 2    ID   16049.0      45.914444     -114.635278 2018-07-24
# 10  NORTH TRAPPER    MT   30081.0      45.938889     -114.271944 2018-08-17
# 11   MARTIN CREEK    MT   30081.0      46.016111     -113.807778 2018-08-11
# 12      MT GEORGE    ID   16049.0      45.907500     -114.626389 2018-07-23
# 13            ELK    MT   30081.0      45.885833     -114.038333 2018-08-21
# 14      HOPE LAKE    MT   30081.0      46.017778     -113.772778 2018-08-12
# 15        CHARITY    MT   30081.0      46.023333     -113.775000 2018-08-11
# 16       CINNABAR    MT   30081.0      46.569444     -113.839167 2018-09-13
# 17  HAYSTACK FIRE    ID   16049.0      45.708333     -114.744444 2018-07-17
# 18      JOHN PEAK    ID   16055.0      47.682778     -116.378611 2018-07-27
# 19       HAMILTON    ID   16055.0      47.867778     -116.376944 2018-07-28
#
#    CONTAIN_DATE              CLOSEST_STATION  STATION_LAT  STATION_LON  \
# 0    2018-08-22              HAMILTON, MT US    46.246220  -114.167940
# 1    2018-07-28  STEVENSVILLE 5.7 SSE, MT US    46.427776  -114.058279
# 2    2018-09-23              HAMILTON, MT US    46.246220  -114.167940
# 3           NaT                 DARBY, MT US    46.026300  -114.176300
# 4    2018-08-12            SULA 14 NE, MT US    45.911000  -113.739400
# 5    2018-08-12            SULA 14 NE, MT US    45.911000  -113.739400
# 6    2018-07-27          SELWAY LODGE, ID US    46.008100  -114.844200
# 7    2018-06-08                 DARBY, MT US    46.026300  -114.176300
# 8           NaT            SULA 14 NE, MT US    45.911000  -113.739400
# 9    2018-07-26          SELWAY LODGE, ID US    46.008100  -114.844200
# 10   2018-10-02                 DARBY, MT US    46.026300  -114.176300
# 11   2018-08-12            SULA 14 NE, MT US    45.911000  -113.739400
# 12   2018-07-25          SELWAY LODGE, ID US    46.008100  -114.844200
# 13          NaT                 DARBY, MT US    46.026300  -114.176300
# 14   2018-08-12            SULA 14 NE, MT US    45.911000  -113.739400
# 15   2018-08-12            SULA 14 NE, MT US    45.911000  -113.739400
# 16   2018-09-13       FLORENCE 3.7 SE, MT US    46.606830  -114.012400
# 17   2018-07-18          SELWAY LODGE, ID US    46.008100  -114.844200
# 18   2018-07-30  COEUR D ALENE 4.0 SE, ID US    47.663000  -116.715000
# 19   2018-07-29   BAYVIEW MODEL BASIN, ID US    47.980400  -116.559400
#
#    READINGS_DATE CAUSE_CLASSIFICATION  FIRE_SIZE FIRE_SIZE_CLASS  ELEVATION  \
# 0     2018-09-01              Natural       0.10               A     1092.7
# 1     2018-08-01                Human       0.10               A     1075.9
# 2     2018-10-01                Human       1.00               B     1092.7
# 3     2018-09-01              Natural       0.10               A     1182.6
# 4     2018-08-01              Natural       0.10               A     1571.2
# 5     2018-08-01              Natural       0.10               A     1571.2
# 6     2018-08-01              Natural       0.10               A      786.4
# 7     2018-06-01              Natural       0.10               A     1182.6
# 8     2018-09-01              Natural       0.25               A     1571.2
# 9     2018-08-01              Natural       0.10               A      786.4
# 10    2018-09-01              Natural       0.10               A     1182.6
# 11    2018-08-01              Natural       0.10               A     1571.2
# 12    2018-08-01              Natural       0.10               A      786.4
# 13    2018-09-01              Natural       0.10               A     1182.6
# 14    2018-08-01              Natural       1.00               B     1571.2
# 15    2018-08-01              Natural       0.10               A     1571.2
# 16    2018-09-01                Human       0.10               A     1085.1
# 17    2018-08-01              Natural       0.10               A      786.4
# 18    2018-08-01              Natural       0.20               A      880.3
# 19    2018-08-01              Natural       0.30               B      636.1
#
#      TAVG   TMAX  TMIN   PRCP  DAYS_TO_CONTAIN
# 0   12.89  21.95  3.82    3.5                0
# 1     NaN    NaN   NaN   12.2                2
# 2    6.96  13.28  0.65   33.7                2
# 3   11.77  20.79  2.74    9.1                0
# 4   15.10  26.09  4.12   19.4                0
# 5   15.10  26.09  4.12   19.4                1
# 6   19.38  31.89  6.88   21.1                2
# 7   14.62  21.15  8.09  102.7                0
# 8    9.69  20.79 -1.42   11.2                0
# 9   19.38  31.89  6.88   21.1                2
# 10  11.77  20.79  2.74    9.1               46
# 11  15.10  26.09  4.12   19.4                1
# 12  19.38  31.89  6.88   21.1                2
# 13  11.77  20.79  2.74    9.1                0
# 14  15.10  26.09  4.12   19.4                0
# 15  15.10  26.09  4.12   19.4                1
# 16    NaN    NaN   NaN    5.4                0
# 17  19.38  31.89  6.88   21.1                1
# 18    NaN    NaN   NaN   21.4                3
# 19  17.32  25.85  8.80   11.0                1

# %%
warnings.filterwarnings("ignore")

us_data_2018 = merged_results[['FIRE_NAME', 'STATE', 'FIPS_CODE', 'LATITUDE', 'LONGITUDE', 'DISCOVERY_DATE', 'CONT_DATE', 'name', 'latitude', 'longitude', 'date',
                                    'NWCG_CAUSE_CLASSIFICATION', 'FIRE_SIZE', 'FIRE_SIZE_CLASS',
                                    'elevation', 'TAVG', 'TMAX', 'TMIN']]

# Rename the columns
us_data_2018.columns = ['FIRE_NAME', 'STATE', 'FIPS_CODE', 'FIRE_LATITUDE', 'FIRE_LONGITUDE', 'FIRE_DATE', 'CONTAIN_DATE', 'CLOSEST_STATION', 'STATION_LAT', 'STATION_LON', 'READINGS_DATE',
                               'CAUSE_CLASSIFICATION', 'FIRE_SIZE', 'FIRE_SIZE_CLASS',
                             'ELEVATION', 'TAVG', 'TMAX', 'TMIN']


# Calculate the difference between 'CONTAIN_DATE' and 'FIRE_DATE'
us_data_2018['CONTAIN_DATE'] = pd.to_datetime(us_data_2018['CONTAIN_DATE'])
us_data_2018['DAYS_TO_CONTAIN'] = (us_data_2018['CONTAIN_DATE'] - us_data_2018['FIRE_DATE']).dt.days

# Replace any NaN values in 'DAYS_TO_CONTAIN' with 1
us_data_2018['DAYS_TO_CONTAIN'].fillna(0, inplace=True)

float_columns = {
    'FIRE_LATITUDE': float,
    'FIRE_LONGITUDE': float,
    'STATION_LAT': float,
    'STATION_LON': float,
    'FIRE_SIZE': float,
    'ELEVATION': float,
    'TAVG': float,
    'TMAX': float,
    'TMIN': float
}

int_columns = {
    'DAYS_TO_CONTAIN': int,
}

us_data_2018 = us_data_2018.astype({**float_columns, **int_columns})

csv_filename = 'Outputs/us_data_2018.csv'
us_data_2018.to_csv(csv_filename, index=False)

us_data_2018.head(20)
# Out:
#         FIRE_NAME STATE FIPS_CODE  FIRE_LATITUDE  FIRE_LONGITUDE  FIRE_DATE  \
# 0        BLODGETT    MT   30081.0      46.275833     -114.379167 2018-08-22
# 1    CORLEY GULCH    MT   30081.0      46.404167     -113.921944 2018-07-26
# 2    CANYON CREEK    MT   30081.0      46.245833     -114.308889 2018-09-21
# 3   MAYNARD CREEK    MT   30081.0      45.784722     -114.033056 2018-08-17
# 4            BLUE    MT   30081.0      45.986944     -113.807222 2018-08-12
# 5        POLLYWOG    MT   30081.0      46.023056     -113.799722 2018-08-11
# 6           CEDAR    ID   16049.0      45.913611     -114.667500 2018-07-25
# 7   DOUBLE STRIKE    MT   30081.0      46.121111     -114.239167 2018-06-08
# 8          MEADOW    MT   30081.0      45.868333     -113.804167 2018-08-17
# 9     MT GEORGE 2    ID   16049.0      45.914444     -114.635278 2018-07-24
# 10  NORTH TRAPPER    MT   30081.0      45.938889     -114.271944 2018-08-17
# 11   MARTIN CREEK    MT   30081.0      46.016111     -113.807778 2018-08-11
# 12      MT GEORGE    ID   16049.0      45.907500     -114.626389 2018-07-23
# 13            ELK    MT   30081.0      45.885833     -114.038333 2018-08-21
# 14      HOPE LAKE    MT   30081.0      46.017778     -113.772778 2018-08-12
# 15        CHARITY    MT   30081.0      46.023333     -113.775000 2018-08-11
# 16       CINNABAR    MT   30081.0      46.569444     -113.839167 2018-09-13
# 17  HAYSTACK FIRE    ID   16049.0      45.708333     -114.744444 2018-07-17
# 18      JOHN PEAK    ID   16055.0      47.682778     -116.378611 2018-07-27
# 19       HAMILTON    ID   16055.0      47.867778     -116.376944 2018-07-28
#
#    CONTAIN_DATE             CLOSEST_STATION  STATION_LAT  STATION_LON  \
# 0    2018-08-22             HAMILTON, MT US     46.24622   -114.16794
# 1    2018-07-28         STEVENSVILLE, MT US     46.51370   -114.09100
# 2    2018-09-23             HAMILTON, MT US     46.24622   -114.16794
# 3           NaT                DARBY, MT US     46.02630   -114.17630
# 4    2018-08-12           SULA 14 NE, MT US     45.91100   -113.73940
# 5    2018-08-12           SULA 14 NE, MT US     45.91100   -113.73940
# 6    2018-07-27         SELWAY LODGE, ID US     46.00810   -114.84420
# 7    2018-06-08                DARBY, MT US     46.02630   -114.17630
# 8           NaT           SULA 14 NE, MT US     45.91100   -113.73940
# 9    2018-07-26         SELWAY LODGE, ID US     46.00810   -114.84420
# 10   2018-10-02                DARBY, MT US     46.02630   -114.17630
# 11   2018-08-12           SULA 14 NE, MT US     45.91100   -113.73940
# 12   2018-07-25         SELWAY LODGE, ID US     46.00810   -114.84420
# 13          NaT                DARBY, MT US     46.02630   -114.17630
# 14   2018-08-12           SULA 14 NE, MT US     45.91100   -113.73940
# 15   2018-08-12           SULA 14 NE, MT US     45.91100   -113.73940
# 16   2018-09-13         STEVENSVILLE, MT US     46.51370   -114.09100
# 17   2018-07-18         SELWAY LODGE, ID US     46.00810   -114.84420
# 18   2018-07-30              KELLOGG, ID US     47.53333   -116.13333
# 19   2018-07-29  BAYVIEW MODEL BASIN, ID US     47.98040   -116.55940
#
#    READINGS_DATE CAUSE_CLASSIFICATION  FIRE_SIZE FIRE_SIZE_CLASS  ELEVATION  \
# 0     2018-09-01              Natural       0.10               A     1092.7
# 1     2018-08-01                Human       0.10               A     1028.7
# 2     2018-10-01                Human       1.00               B     1092.7
# 3     2018-09-01              Natural       0.10               A     1182.6
# 4     2018-08-01              Natural       0.10               A     1571.2
# 5     2018-08-01              Natural       0.10               A     1571.2
# 6     2018-08-01              Natural       0.10               A      786.4
# 7     2018-06-01              Natural       0.10               A     1182.6
# 8     2018-09-01              Natural       0.25               A     1571.2
# 9     2018-08-01              Natural       0.10               A      786.4
# 10    2018-09-01              Natural       0.10               A     1182.6
# 11    2018-08-01              Natural       0.10               A     1571.2
# 12    2018-08-01              Natural       0.10               A      786.4
# 13    2018-09-01              Natural       0.10               A     1182.6
# 14    2018-08-01              Natural       1.00               B     1571.2
# 15    2018-08-01              Natural       0.10               A     1571.2
# 16    2018-09-01                Human       0.10               A     1028.7
# 17    2018-08-01              Natural       0.10               A      786.4
# 18    2018-08-01              Natural       0.20               A      702.6
# 19    2018-08-01              Natural       0.30               B      636.1
#
#      TAVG   TMAX  TMIN  DAYS_TO_CONTAIN
# 0   12.89  21.95  3.82                0
# 1   18.29  28.05  8.53                2
# 2    6.96  13.28  0.65                2
# 3   11.77  20.79  2.74                0
# 4   15.10  26.09  4.12                0
# 5   15.10  26.09  4.12                1
# 6   19.38  31.89  6.88                2
# 7   14.62  21.15  8.09                0
# 8    9.69  20.79 -1.42                0
# 9   19.38  31.89  6.88                2
# 10  11.77  20.79  2.74               46
# 11  15.10  26.09  4.12                1
# 12  19.38  31.89  6.88                2
# 13  11.77  20.79  2.74                0
# 14  15.10  26.09  4.12                0
# 15  15.10  26.09  4.12                1
# 16  13.31  23.74  2.87                0
# 17  19.38  31.89  6.88                1
# 18  18.96  29.37  8.56                3
# 19  17.32  25.85  8.80                1

# %%
csv_filename = 'Outputs/us_data_2018.csv'
us_data_2018.to_csv(csv_filename, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24392\2368424073.py in <module>
#       1 csv_filename = 'Outputs/us_data_2018.csv'
# ----> 2 us_data_2018.to_csv(csv_filename, index=False)
#
# NameError: name 'us_data_2018' is not defined
